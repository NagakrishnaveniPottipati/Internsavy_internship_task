# %%
# Disable all warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error as mae, mean_squared_error as mse

# %%
bats_df = pd.read_csv('/content/Batsman_Data.csv')

# %%
bats_df
# Out:
#        Unnamed: 0  Bat1 Runs  BF     SR 4s 6s    Opposition     Ground  \
# 0               1   DNB    -   -      -  -  -       v India     Nagpur
# 1               2   DNB    -   -      -  -  -       v India    Kolkata
# 2               3   DNB    -   -      -  -  -       v India      Delhi
# 3               4   DNB    -   -      -  -  -  v Bangladesh      Dhaka
# 4               5   DNB    -   -      -  -  -       v India      Dhaka
# ...           ...   ...  ...  ..    ... .. ..           ...        ...
# 11144       11145    46   46  61  75.40  6  1     v Ireland   Dehradun
# 11145       11146     3    3   6  50.00  0  0     v Ireland   Dehradun
# 11146       11147     1    1   8  12.50  0  0     v Ireland   Dehradun
# 11147       11148   DNB    -   -      -  -  -    v Scotland  Edinburgh
# 11148       11149  TDNB    -   -      -  -  -     v Ireland    Belfast
#
#         Start Date    Match_ID         Batsman  Player_ID
# 0      18 Dec 2009  ODI # 2933   Oshane Thomas      49619
# 1      24 Dec 2009  ODI # 2935   Oshane Thomas      49619
# 2      27 Dec 2009  ODI # 2936   Oshane Thomas      49619
# 3       4 Jan 2010  ODI # 2937   Oshane Thomas      49619
# 4       5 Jan 2010  ODI # 2938   Oshane Thomas      49619
# ...            ...         ...             ...        ...
# 11144  28 Feb 2019  ODI # 4100  Gulbadin Naib      352048
# 11145   2 Mar 2019  ODI # 4101  Gulbadin Naib      352048
# 11146   8 Mar 2019  ODI # 4108  Gulbadin Naib      352048
# 11147  10 May 2019  ODI # 4131  Gulbadin Naib      352048
# 11148  19 May 2019  ODI # 4139  Gulbadin Naib      352048
#
# [11149 rows x 13 columns]

# %%
bowl_df = pd.read_csv('/content/Bowler_data.csv')

# %%
bowl_df
# Out:
#        Unnamed: 0 Overs Mdns Runs Wkts   Econ    Ave    SR    Opposition  \
# 0               1   8.0    0   57    0   7.12      -     -       v India
# 1               2  10.0    0   55    2   5.50  27.50  30.0       v India
# 2               3     -    -    -    -      -      -     -       v India
# 3               4   9.0    1   63    2   7.00  31.50  27.0  v Bangladesh
# 4               5   8.0    1   48    0   6.00      -     -       v India
# ...           ...   ...  ...  ...  ...    ...    ...   ...           ...
# 11113       11114   4.0    0   41    0  10.25      -     -       v India
# 11114       11115   7.2    0   20    2   2.72  10.00  22.0     v Ireland
# 11115       11116     -    -    -    -      -      -     -     v Ireland
# 11116       11117   6.0    0   21    1   3.50  21.00  36.0     v Ireland
# 11117       11118  10.0    0   72    3   7.20  24.00  20.0    v Scotland
#
#             Ground   Start Date    Match_ID          Bowler  Player_ID
# 0           Nagpur  18 Dec 2009  ODI # 2933  Suranga Lakmal      49619
# 1          Kolkata  24 Dec 2009  ODI # 2935  Suranga Lakmal      49619
# 2            Delhi  27 Dec 2009  ODI # 2936  Suranga Lakmal      49619
# 3            Dhaka   4 Jan 2010  ODI # 2937  Suranga Lakmal      49619
# 4            Dhaka   5 Jan 2010  ODI # 2938  Suranga Lakmal      49619
# ...            ...          ...         ...             ...        ...
# 11113  Dubai (DSC)  25 Sep 2018  ODI # 4046  Gulbadin Naib      352048
# 11114     Dehradun  28 Feb 2019  ODI # 4100  Gulbadin Naib      352048
# 11115     Dehradun   2 Mar 2019  ODI # 4101  Gulbadin Naib      352048
# 11116     Dehradun   8 Mar 2019  ODI # 4108  Gulbadin Naib      352048
# 11117    Edinburgh  10 May 2019  ODI # 4131  Gulbadin Naib      352048
#
# [11118 rows x 14 columns]

# %%
ground_df = pd.read_csv('/content/Ground_Averages.csv')

# %%
ground_df.head()
# Out:
#                                               Ground       Span  Mat  Won  \
# 0                      Eden Gardens, Kolkata - India  2013-2017    4    4
# 1                    Feroz Shah Kotla, Delhi - India  2013-2019    4    4
# 2               Melbourne Cricket Ground - Australia  2013-2019   15   15
# 3  Saurashtra Cricket Association Stadium, Rajkot...  2013-2015    2    2
# 4                          Adelaide Oval - Australia  2013-2019   10   10
#
#    Tied  NR  Runs  Wkts  Balls    Ave   RPO
# 0     0   0  2161    72   2297  30.01  5.64
# 1     0   0  1789    75   2331  23.85  4.60
# 2     0   0  7656   217   8482  35.28  5.41
# 3     0   0  1163    26   1200  44.73  5.81
# 4     0   0  4863   157   5645  30.97  5.16

# %%
match_results = pd.read_csv('/content/ODI_Match_Results.csv')

# %%
match_results
# Out:
#       Unnamed: 0 Result     Margin   BR  Toss  Bat   Opposition      Ground  \
# 0            418    won    85 runs  NaN  lost  1st      v India     Kolkata
# 1            692   lost    85 runs  NaN   won  2nd   v Pakistan     Kolkata
# 2            419   lost    10 runs  NaN  lost  2nd      v India       Delhi
# 3            693    won    10 runs  NaN   won  1st   v Pakistan       Delhi
# 4            121   lost   107 runs  NaN  lost  2nd  v Australia   Melbourne
# ...          ...    ...        ...  ...   ...  ...          ...         ...
# 1317         997    won  3 wickets  3.0   won  2nd   v Pakistan  Nottingham
# 1318         282   aban          -  NaN     -    -   v Scotland   Edinburgh
# 1319        1322      -          -  NaN   won  2nd    v Ireland     Belfast
# 1320         559      -          -  NaN  lost  2nd    v England       Leeds
# 1321         998      -          -  NaN   won  1st   v Pakistan       Leeds
#
#        Start Date     Match_ID      Country  Country_ID
# 0      3 Jan 2013   ODI # 3315     Pakistan           7
# 1      3 Jan 2013   ODI # 3315        India           6
# 2      6 Jan 2013   ODI # 3316     Pakistan           7
# 3      6 Jan 2013   ODI # 3316        India           6
# 4     11 Jan 2013   ODI # 3317     SriLanka           8
# ...           ...          ...          ...         ...
# 1317  17 May 2019   ODI # 4138      England           1
# 1318  18 May 2019  ODI # 4138a     SriLanka           8
# 1319  19 May 2019   ODI # 4139  Afghanistan          40
# 1320  19 May 2019   ODI # 4140     Pakistan           7
# 1321  19 May 2019   ODI # 4140      England           1
#
# [1322 rows x 12 columns]

# %%
match_totals = pd.read_csv('/content/ODI_Match_Totals.csv')

# %%
match_totals
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result   Opposition  \
# 0            412    250   48.3  5.15     NaN     1    won      v India
# 1            680    165   48.0  3.43   251.0     2   lost   v Pakistan
# 2            413    157   48.5  3.21   168.0     2   lost      v India
# 3            681    167   43.4  3.82     NaN     1    won   v Pakistan
# 4            117    198   40.0  4.95   306.0     2   lost  v Australia
# ...          ...    ...    ...   ...     ...   ...    ...          ...
# 1291         549  340/7   50.0  6.80     NaN     1   lost    v England
# 1292         979  341/7   49.3  6.88   341.0     2    won   v Pakistan
# 1293        1296  120/8   33.0  3.63   211.0     2      -    v Ireland
# 1294         550  193/6   31.5  6.06   352.0     2      -    v England
# 1295         980  351/9   50.0  7.02     NaN     1      -   v Pakistan
#
#           Ground   Start Date    Match_ID      Country  Country_ID
# 0        Kolkata   3 Jan 2013  ODI # 3315     Pakistan           7
# 1        Kolkata   3 Jan 2013  ODI # 3315        India           6
# 2          Delhi   6 Jan 2013  ODI # 3316     Pakistan           7
# 3          Delhi   6 Jan 2013  ODI # 3316        India           6
# 4      Melbourne  11 Jan 2013  ODI # 3317     SriLanka           8
# ...          ...          ...         ...          ...         ...
# 1291  Nottingham  17 May 2019  ODI # 4138     Pakistan           7
# 1292  Nottingham  17 May 2019  ODI # 4138      England           1
# 1293     Belfast  19 May 2019  ODI # 4139  Afghanistan          40
# 1294       Leeds  19 May 2019  ODI # 4140     Pakistan           7
# 1295       Leeds  19 May 2019  ODI # 4140      England           1
#
# [1296 rows x 13 columns]

# %%
wc_player = pd.read_csv('/content/WC_players.csv')

# %%
wc_player
# Out:
#                    Player      ID      Country
# 0       Gulbadin Naib (c)  352048  Afghanistan
# 1        Rashid Khan (vc)  793463  Afghanistan
# 2              Aftab Alam  440963  Afghanistan
# 3           Asghar Afghan  320652  Afghanistan
# 4           Dawlat Zadran  516561  Afghanistan
# ..                    ...     ...          ...
# 147          Ashley Nurse  315594   WestIndies
# 148  Nicholas Pooran (wk)  604302   WestIndies
# 149           Kemar Roach  230553   WestIndies
# 150         Andre Russell  276298   WestIndies
# 151         Oshane Thomas  914567   WestIndies
#
# [152 rows x 3 columns]

# %%
bats_df.isnull().sum()
# Out:
# Bat1          0
# Runs          0
# BF            0
# SR            0
# 4s            0
# 6s            0
# Opposition    0
# Ground        0
# Match_ID      0
# Batsman       0
# Player_ID     0
# Month         0
# Day           0
# year          0
# dtype: int64

# %%
bowl_df.isnull().sum()
# Out:
# Overs         0
# Mdns          0
# Runs          0
# Wkts          0
# Econ          0
# Ave           0
# SR            0
# Opposition    0
# Ground        0
# Match_ID      0
# Bowler        0
# Player_ID     0
# Month         0
# Day           0
# year          0
# dtype: int64

# %%
ground_df.isnull().sum()
# Out:
# Ground    0
# Span      0
# Mat       0
# Won       0
# Tied      0
# NR        0
# Runs      0
# Wkts      0
# Balls     0
# Ave       0
# RPO       0
# dtype: int64

# %%
match_results.isnull().sum()
# Out:
# Score         0
# Overs         0
# RPO           0
# Target        0
# Inns          0
# Result        0
# Opposition    0
# Ground        0
# Match_ID      0
# Country       0
# Country_ID    0
# Month         0
# Day           0
# year          0
# dtype: int64

# %%
match_totals.isnull().sum()
# Out:
# Result        0
# Margin        0
# BR            0
# Toss          0
# Bat           0
# Opposition    0
# Ground        0
# Match_ID      0
# Country       0
# Country_ID    0
# Month         0
# Day           0
# year          0
# dtype: int64

# %%
wc_player.isnull().sum()
# Out:
# Player     0
# ID         0
# Country    0
# dtype: int64

# %%
bats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11149 entries, 0 to 11148
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Bat1        11149 non-null  int64
#  1   Runs        11149 non-null  int64
#  2   BF          11149 non-null  int64
#  3   SR          11149 non-null  int64
#  4   4s          11149 non-null  int64
#  5   6s          11149 non-null  int64
#  6   Opposition  11149 non-null  int64
#  7   Ground      11149 non-null  int64
#  8   Match_ID    11149 non-null  int64
#  9   Batsman     11149 non-null  int64
#  10  Player_ID   11149 non-null  int64
#  11  Month       11149 non-null  int64
#  12  Day         11149 non-null  int64
#  13  year        11149 non-null  int64
# dtypes: int64(14)
# memory usage: 1.2 MB

# %%
bowl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11118 entries, 0 to 11117
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Overs       11118 non-null  int64
#  1   Mdns        11118 non-null  int64
#  2   Runs        11118 non-null  int64
#  3   Wkts        11118 non-null  int64
#  4   Econ        11118 non-null  int64
#  5   Ave         11118 non-null  int64
#  6   SR          11118 non-null  int64
#  7   Opposition  11118 non-null  int64
#  8   Ground      11118 non-null  int64
#  9   Match_ID    11118 non-null  int64
#  10  Bowler      11118 non-null  int64
#  11  Player_ID   11118 non-null  int64
#  12  Month       11118 non-null  int64
#  13  Day         11118 non-null  int64
#  14  year        11118 non-null  int64
# dtypes: int64(15)
# memory usage: 1.3 MB

# %%
ground_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ground  106 non-null    int64
#  1   Span    106 non-null    int64
#  2   Mat     106 non-null    int64
#  3   Won     106 non-null    int64
#  4   Tied    106 non-null    int64
#  5   NR      106 non-null    int64
#  6   Runs    106 non-null    int64
#  7   Wkts    106 non-null    int64
#  8   Balls   106 non-null    int64
#  9   Ave     106 non-null    float64
#  10  RPO     106 non-null    float64
# dtypes: float64(2), int64(9)
# memory usage: 9.2 KB

# %%
match_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Score       1296 non-null   float64
#  1   Overs       1296 non-null   float64
#  2   RPO         1296 non-null   float64
#  3   Target      1296 non-null   float64
#  4   Inns        1296 non-null   float64
#  5   Result      1296 non-null   float64
#  6   Opposition  1296 non-null   float64
#  7   Ground      1296 non-null   float64
#  8   Match_ID    1296 non-null   float64
#  9   Country     1296 non-null   float64
#  10  Country_ID  1296 non-null   float64
#  11  Month       1296 non-null   float64
#  12  Day         1296 non-null   float64
#  13  year        1296 non-null   float64
# dtypes: float64(14)
# memory usage: 141.9 KB

# %%
match_totals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1322 entries, 0 to 1321
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Result      1322 non-null   float64
#  1   Margin      1322 non-null   float64
#  2   BR          1322 non-null   float64
#  3   Toss        1322 non-null   float64
#  4   Bat         1322 non-null   float64
#  5   Opposition  1322 non-null   float64
#  6   Ground      1322 non-null   float64
#  7   Match_ID    1322 non-null   float64
#  8   Country     1322 non-null   float64
#  9   Country_ID  1322 non-null   float64
#  10  Month       1322 non-null   float64
#  11  Day         1322 non-null   float64
#  12  year        1322 non-null   float64
# dtypes: float64(13)
# memory usage: 134.4 KB

# %%
wc_player.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   152 non-null    object
#  1   ID       152 non-null    int64
#  2   Country  152 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 3.7+ KB

# %%
df=[bats_df,bowl_df,ground_df,match_results,match_totals,wc_player]

# %%
def dementions(df):
    for i in df:
        print(i.shape)
        print('*'*100)
        print(i.info())
        print('*'*100)
        print(i.isna().sum())

# %%
dementions(df)
# Out:
# (11149, 14)
# ****************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11149 entries, 0 to 11148
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Bat1        11149 non-null  int64
#  1   Runs        11149 non-null  int64
#  2   BF          11149 non-null  int64
#  3   SR          11149 non-null  int64
#  4   4s          11149 non-null  int64
#  5   6s          11149 non-null  int64
#  6   Opposition  11149 non-null  int64
#  7   Ground      11149 non-null  int64
#  8   Match_ID    11149 non-null  int64
#  9   Batsman     11149 non-null  int64
#  10  Player_ID   11149 non-null  int64
#  11  Month       11149 non-null  int64
#  12  Day         11149 non-null  int64
#  13  year        11149 non-null  int64
# dtypes: int64(14)
# memory usage: 1.2 MB
# None
# ****************************************************************************************************
# Bat1          0
# Runs          0
# BF            0
# SR            0
# 4s            0
# 6s            0
# Opposition    0
# Ground        0
# Match_ID      0
# Batsman       0
# Player_ID     0
# Month         0
# Day           0
# year          0
# dtype: int64
# (11118, 15)
# ****************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11118 entries, 0 to 11117
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Overs       11118 non-null  int64
#  1   Mdns        11118 non-null  int64
#  2   Runs        11118 non-null  int64
#  3   Wkts        11118 non-null  int64
#  4   Econ        11118 non-null  int64
#  5   Ave         11118 non-null  int64
#  6   SR          11118 non-null  int64
#  7   Opposition  11118 non-null  int64
#  8   Ground      11118 non-null  int64
#  9   Match_ID    11118 non-null  int64
#  10  Bowler      11118 non-null  int64
#  11  Player_ID   11118 non-null  int64
#  12  Month       11118 non-null  int64
#  13  Day         11118 non-null  int64
#  14  year        11118 non-null  int64
# dtypes: int64(15)
# memory usage: 1.3 MB
# None
# ****************************************************************************************************
# Overs         0
# Mdns          0
# Runs          0
# Wkts          0
# Econ          0
# Ave           0
# SR            0
# Opposition    0
# Ground        0
# Match_ID      0
# Bowler        0
# Player_ID     0
# Month         0
# Day           0
# year          0
# dtype: int64
# (106, 11)
# ****************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ground  106 non-null    int64
#  1   Span    106 non-null    int64
#  2   Mat     106 non-null    int64
#  3   Won     106 non-null    int64
#  4   Tied    106 non-null    int64
#  5   NR      106 non-null    int64
#  6   Runs    106 non-null    int64
#  7   Wkts    106 non-null    int64
#  8   Balls   106 non-null    int64
#  9   Ave     106 non-null    float64
#  10  RPO     106 non-null    float64
# dtypes: float64(2), int64(9)
# memory usage: 9.2 KB
# None
# ****************************************************************************************************
# Ground    0
# Span      0
# Mat       0
# Won       0
# Tied      0
# NR        0
# Runs      0
# Wkts      0
# Balls     0
# Ave       0
# RPO       0
# dtype: int64
# (1296, 14)
# ****************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Score       1296 non-null   float64
#  1   Overs       1296 non-null   float64
#  2   RPO         1296 non-null   float64
#  3   Target      1296 non-null   float64
#  4   Inns        1296 non-null   float64
#  5   Result      1296 non-null   float64
#  6   Opposition  1296 non-null   float64
#  7   Ground      1296 non-null   float64
#  8   Match_ID    1296 non-null   float64
#  9   Country     1296 non-null   float64
#  10  Country_ID  1296 non-null   float64
#  11  Month       1296 non-null   float64
#  12  Day         1296 non-null   float64
#  13  year        1296 non-null   float64
# dtypes: float64(14)
# memory usage: 141.9 KB
# None
# ****************************************************************************************************
# Score         0
# Overs         0
# RPO           0
# Target        0
# Inns          0
# Result        0
# Opposition    0
# Ground        0
# Match_ID      0
# Country       0
# Country_ID    0
# Month         0
# Day           0
# year          0
# dtype: int64
# (1322, 13)
# ****************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1322 entries, 0 to 1321
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Result      1322 non-null   float64
#  1   Margin      1322 non-null   float64
#  2   BR          1322 non-null   float64
#  3   Toss        1322 non-null   float64
#  4   Bat         1322 non-null   float64
#  5   Opposition  1322 non-null   float64
#  6   Ground      1322 non-null   float64
#  7   Match_ID    1322 non-null   float64
#  8   Country     1322 non-null   float64
#  9   Country_ID  1322 non-null   float64
#  10  Month       1322 non-null   float64
#  11  Day         1322 non-null   float64
#  12  year        1322 non-null   float64
# dtypes: float64(13)
# memory usage: 134.4 KB
# None
# ****************************************************************************************************
# Result        0
# Margin        0
# BR            0
# Toss          0
# Bat           0
# Opposition    0
# Ground        0
# Match_ID      0
# Country       0
# Country_ID    0
# Month         0
# Day           0
# year          0
# dtype: int64
# (152, 3)
# ****************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   152 non-null    object
#  1   ID       152 non-null    int64
#  2   Country  152 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 3.7+ KB
# None
# ****************************************************************************************************
# Player     0
# ID         0
# Country    0
# dtype: int64

# %%
def stat_summary(df):
    for i in df:
        print(i.describe(include='all'))
        print('*'*100)

# %%
stat_summary(df)
# Out:
#                Bat1          Runs            BF            SR            4s  \
# count  11149.000000  11149.000000  11149.000000  11149.000000  11149.000000
# mean     181.407750     69.588842     68.264867    709.145305      7.411158
# std      106.841924     58.830457     50.727201    637.727284      8.747501
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      112.000000      1.000000      3.000000      1.000000      1.000000
# 50%      187.000000     86.000000     79.000000    717.000000      2.000000
# 75%      277.000000    119.000000    108.000000   1227.000000     18.000000
# max      322.000000    179.000000    162.000000   2031.000000     25.000000
#
#                  6s    Opposition        Ground      Match_ID       Batsman  \
# count  11149.000000  11149.000000  11149.000000  11149.000000  11149.000000
# mean       1.789219     12.425957     60.383891   1300.282447     78.954166
# std        2.751499      6.066446     39.070758    435.820089     42.904241
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      7.000000     29.000000   1044.000000     40.000000
# 50%        1.000000     13.000000     54.000000   1416.000000     83.000000
# 75%        1.000000     18.000000     98.000000   1653.000000    119.000000
# max       16.000000     21.000000    133.000000   1843.000000    148.000000
#
#           Player_ID         Month           Day          year
# count  1.114900e+04  11149.000000  11149.000000  11149.000000
# mean   2.259088e+05      5.912817     15.931743   2014.164230
# std    1.942613e+05      3.617762      8.620279      3.902773
# min    5.334000e+03      1.000000      1.000000   1999.000000
# 25%    4.749200e+04      2.000000      9.000000   2012.000000
# 50%    2.335140e+05      6.000000     16.000000   2015.000000
# 75%    3.217770e+05      9.000000     23.000000   2017.000000
# max    1.158100e+06     12.000000     31.000000   2019.000000
# ****************************************************************************************************
#               Overs          Mdns          Runs          Wkts          Econ  \
# count  11118.000000  11118.000000  11118.000000  11118.000000  11118.000000
# mean      15.449541      0.687804     21.068987      1.134197    146.052258
# std       19.246864      0.795856     24.431082      1.393833    160.324570
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%       12.000000      1.000000     12.000000      1.000000     84.000000
# 75%       31.000000      1.000000     40.000000      2.000000    288.000000
# max       60.000000      5.000000     99.000000      8.000000    516.000000
#
#                 Ave            SR    Opposition        Ground      Match_ID  \
# count  11118.000000  11118.000000  11118.000000  11118.000000  11118.000000
# mean      36.671344     24.652815     12.430923     60.398633   1298.770192
# std       63.198586     39.389503      6.071746     39.080696    435.483923
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      7.000000     29.000000   1042.000000
# 50%        0.000000      0.000000     13.000000     54.000000   1415.000000
# 75%       59.000000     56.000000     18.000000     98.000000   1651.000000
# max      249.000000    134.000000     21.000000    133.000000   1841.000000
#
#              Bowler     Player_ID         Month           Day          year
# count  11118.000000  1.111800e+04  11118.000000  11118.000000  11118.000000
# mean      79.265156  2.254082e+05      5.915362     15.923188   2014.150747
# std       43.226149  1.936517e+05      3.622481      8.630765      3.899836
# min        0.000000  5.334000e+03      1.000000      1.000000   1999.000000
# 25%       40.000000  4.557200e+04      2.000000      9.000000   2012.000000
# 50%       83.000000  2.335140e+05      6.000000     16.000000   2015.000000
# 75%      120.000000  3.217770e+05      9.000000     23.000000   2017.000000
# max      149.000000  1.158100e+06     12.000000     31.000000   2019.000000
# ****************************************************************************************************
#            Ground        Span         Mat         Won        Tied          NR  \
# count  106.000000  106.000000  106.000000  106.000000  106.000000  106.000000
# mean    52.500000    8.056604    7.792453    7.367925    0.094340    0.311321
# std     30.743563    5.008241    8.285061    8.022974    0.324501    0.622793
# min      0.000000    0.000000    1.000000    1.000000    0.000000    0.000000
# 25%     26.250000    5.000000    2.250000    2.000000    0.000000    0.000000
# 50%     52.500000    6.000000    5.000000    5.000000    0.000000    0.000000
# 75%     78.750000   10.000000   10.000000   10.000000    0.000000    0.000000
# max    105.000000   19.000000   50.000000   50.000000    2.000000    3.000000
#
#                Runs        Wkts         Balls         Ave         RPO
# count    106.000000  106.000000    106.000000  106.000000  106.000000
# mean    3582.500000  112.103774   4031.896226   34.216604    5.458113
# std     3575.148949  122.883602   4296.526140   11.367913    0.756841
# min      209.000000    6.000000    252.000000   15.540000    3.880000
# 25%     1239.250000   34.000000   1229.000000   28.800000    4.990000
# 50%     2283.500000   75.000000   2777.500000   32.775000    5.440000
# 75%     4759.500000  137.250000   5279.500000   36.282500    5.757500
# max    20917.000000  739.000000  26328.000000  120.160000    9.690000
# ****************************************************************************************************
#              Score        Overs          RPO       Target         Inns  \
# count  1296.000000  1296.000000  1296.000000  1296.000000  1296.000000
# mean    420.794753    43.087423   188.158179   267.583440     1.462963
# std     237.973736    10.632343    92.841229    62.616505     0.528875
# min       0.000000     0.000000     0.000000    68.000000     0.000000
# 25%     226.000000    40.200000   119.750000   232.143747     1.000000
# 50%     412.500000    48.200000   189.000000   275.816348     1.000000
# 75%     616.250000    50.000000   252.000000   309.000000     2.000000
# max     863.000000    50.000000   394.000000   482.000000     2.000000
#
#             Result   Opposition       Ground     Match_ID      Country  \
# count  1296.000000  1296.000000  1296.000000  1296.000000  1296.000000
# mean      2.595679     8.831019    45.863426   368.547840     4.728395
# std       1.465204     5.491305    27.648913   215.929999     2.753221
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     3.000000    23.000000   179.750000     3.000000
# 50%       4.000000     9.000000    44.000000   371.000000     5.000000
# 75%       4.000000    14.000000    72.000000   554.250000     7.000000
# max       4.000000    17.000000    93.000000   741.000000     9.000000
#
#         Country_ID        Month          Day         year
# count  1296.000000  1296.000000  1296.000000  1296.000000
# mean      8.553241     5.926698    16.152006  2015.673611
# std      10.330236     3.678597     8.645710     1.922622
# min       1.000000     1.000000     1.000000  2013.000000
# 25%       3.000000     2.000000     9.000000  2014.000000
# 50%       5.000000     6.000000    17.000000  2015.000000
# 75%       8.000000     9.000000    24.000000  2017.000000
# max      40.000000    12.000000    31.000000  2019.000000
# ****************************************************************************************************
#             Result       Margin           BR         Toss          Bat  \
# count  1322.000000  1322.000000  1322.000000  1322.000000  1322.000000
# mean      4.523449    99.066566    46.809648     1.463691     1.458396
# std       1.538743    52.286291    39.207886     0.536874     0.542104
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000    65.000000    24.000000     1.000000     1.000000
# 50%       6.000000   111.000000    41.000000     1.000000     1.000000
# 75%       6.000000   142.000000    56.093841     2.000000     2.000000
# max       6.000000   172.000000   250.000000     2.000000     2.000000
#
#         Opposition       Ground     Match_ID      Country   Country_ID  \
# count  1322.000000  1322.000000  1322.000000  1322.000000  1322.000000
# mean      8.796520    45.842663   376.308623     4.722390     8.560514
# std       5.481803    27.603570   220.491805     2.756743    10.337003
# min       0.000000     0.000000     0.000000     0.000000     1.000000
# 25%       3.000000    23.000000   183.250000     3.000000     3.000000
# 50%       9.000000    44.000000   378.000000     5.000000     5.000000
# 75%      14.000000    72.000000   566.750000     7.000000     8.000000
# max      17.000000    93.000000   758.000000     9.000000    40.000000
#
#              Month          Day         year
# count  1322.000000  1322.000000  1322.000000
# mean      5.944024    16.172466  2015.661120
# std       3.676331     8.644316     1.925207
# min       1.000000     1.000000  2013.000000
# 25%       2.000000     9.000000  2014.000000
# 50%       6.000000    17.000000  2015.000000
# 75%       9.000000    24.000000  2017.000000
# max      12.000000    31.000000  2019.000000
# ****************************************************************************************************
#                    Player            ID    Country
# count                 152  1.520000e+02        152
# unique                152           NaN         10
# top     Gulbadin Naib (c)           NaN  Australia
# freq                    1           NaN         16
# mean                  NaN  3.542758e+05        NaN
# std                   NaN  2.361571e+05        NaN
# min                   NaN  5.334000e+03        NaN
# 25%                   NaN  2.298578e+05        NaN
# 50%                   NaN  3.230675e+05        NaN
# 75%                   NaN  4.942175e+05        NaN
# max                   NaN  1.158100e+06        NaN
# ****************************************************************************************************

# %%
# As our data set has start date or date column so lets first seaprate them into day, month and year wise and drop the orignal one
def seperate_date(df):
    for i in range(len(df)):
        if 'Start Date' in df[i].columns:
            df[i]['Year']=pd.to_datetime(df[i]['Start Date'])
            df[i]['Month']=df[i]['Year'].apply(lambda x:x.month) # Extracting Month
            df[i]['Day']=df[i]['Year'].apply(lambda x:x.day)  # Extracting day
            df[i]['year']=df[i]['Year'].apply(lambda x:x.year)  # Extracting year
            print(df[i].head())
            print("-------------------------")
        else:
            print("DataFrame", i, "does not have 'Satrt Date' column")
            print("-------------------------")

# %%
seperate_date(df)
# Out:
# DataFrame 0 does not have 'Satrt Date' column
# -------------------------
# DataFrame 1 does not have 'Satrt Date' column
# -------------------------
# DataFrame 2 does not have 'Satrt Date' column
# -------------------------
# DataFrame 3 does not have 'Satrt Date' column
# -------------------------
# DataFrame 4 does not have 'Satrt Date' column
# -------------------------
# DataFrame 5 does not have 'Satrt Date' column
# -------------------------

# %%
# Drop irrelavent columns from the datasets
def drop_irrelevant(df):
    for i in range(len(df)):
        columns_to_drop = ['Unnamed: 0', 'Start Date', 'Year']
        irrelevant_columns = [col for col in columns_to_drop if col in df[i].columns]

        if irrelevant_columns:
            df[i].drop(columns=irrelevant_columns, axis=1, inplace=True)
            print("DataFrame", i, "after dropping irrelevant columns:")
            print(df[i].head())  # Printing the DataFrame after dropping columns
            print("-------------------------")
        else:
            print("DataFrame", i, "does not have any irrelevant columns")
            print("-------------------------")

# %%
drop_irrelevant(df)
# Out:
# DataFrame 0 does not have any irrelevant columns
# -------------------------
# DataFrame 1 does not have any irrelevant columns
# -------------------------
# DataFrame 2 does not have any irrelevant columns
# -------------------------
# DataFrame 3 does not have any irrelevant columns
# -------------------------
# DataFrame 4 does not have any irrelevant columns
# -------------------------
# DataFrame 5 does not have any irrelevant columns
# -------------------------

# %%
df_list=[bats_df,bowl_df,ground_df,match_results,match_totals,wc_player]

# %%
# As we seen there are object type of data avilabe in the all the dataset so lets seaprate them and encode them into numeric form .
# lets seaprate the catogorical data & numirical data

numerics = ['int8', 'int16', 'int32', 'int64', 'float16', 'float32', 'float64']

def get_categorical_columns(df_list):
    cat_col_list = []  # List to store categorical column names for each DataFrame

    for df in df_list:
        cat_col = []  # List to store categorical column names for the current DataFrame
        features = df.columns.values.tolist()

        for col in features:
            if df[col].dtype not in numerics:  # Check if the column's data type is non-numeric
                cat_col.append(col)

        cat_col_list.append(cat_col)

    return cat_col_list
def label_encode_categorical_columns(df_list):
    label = LabelEncoder()

    categorical_columns_list = get_categorical_columns(df_list)

    for i, cat_col in enumerate(categorical_columns_list):
        for col in cat_col:
            encoded_values = label.fit_transform(df_list[i][col])
            df_list[i][col] = encoded_values

# %%
label_encode_categorical_columns(df_list)

# %%
bats_df.head()
# Out:
#    Bat1  Runs  BF  SR  4s  6s  Opposition  Ground  Match_ID  Batsman  \
# 0   319     0   0   0   0   0           9      92       759      113
# 1   319     0   0   0   0   0           9      78       761      113
# 2   319     0   0   0   0   0           9      37       762      113
# 3   319     0   0   0   0   0           4      38       763      113
# 4   319     0   0   0   0   0           9      38       764      113
#
#    Player_ID  Month  Day  year
# 0      49619     12   18  2009
# 1      49619     12   24  2009
# 2      49619     12   27  2009
# 3      49619      1    4  2010
# 4      49619      1    5  2010

# %%
bowl_df.head()
# Out:
#    Overs  Mdns  Runs  Wkts  Econ  Ave  SR  Opposition  Ground  Match_ID  \
# 0     49     1    59     1   412    0   0           9      92       759
# 1     12     1    57     3   316  103  77           9      78       761
# 2      0     0     0     0     0    0   0           9      37       762
# 3     55     2    66     3   406  120  70           4      38       763
# 4     49     2    49     1   349    0   0           9      38       764
#
#    Bowler  Player_ID  Month  Day  year
# 0     138      49619     12   18  2009
# 1     138      49619     12   24  2009
# 2     138      49619     12   27  2009
# 3     138      49619      1    4  2010
# 4     138      49619      1    5  2010

# %%
ground_df.head()
# Out:
#    Ground  Span  Mat  Won  Tied  NR  Runs  Wkts  Balls    Ave   RPO
# 0      23     4    4    4     0   0  2161    72   2297  30.01  5.64
# 1      26     6    4    4     0   0  1789    75   2331  23.85  4.60
# 2      55     6   15   15     0   0  7656   217   8482  35.28  5.41
# 3      76     2    2    2     0   0  1163    26   1200  44.73  5.81
# 4       0     6   10   10     0   0  4863   157   5645  30.97  5.16

# %%
match_results.head()
# Out:
#    Score  Overs    RPO      Target  Inns  Result  Opposition  Ground  \
# 0  404.0   48.3  165.0  241.723435   1.0     4.0         5.0    57.0
# 1  115.0   48.0   25.0  251.000000   2.0     1.0        11.0    57.0
# 2   93.0   48.5   18.0  168.000000   2.0     1.0         5.0    29.0
# 3  120.0   43.4   48.0  176.027214   1.0     4.0        11.0    29.0
# 4  199.0   40.0  146.0  306.000000   2.0     1.0         1.0    63.0
#
#    Match_ID  Country  Country_ID  Month   Day    year
# 0       0.0      6.0         7.0    1.0   3.0  2013.0
# 1       0.0      4.0         6.0    1.0   3.0  2013.0
# 2       1.0      6.0         7.0    1.0   6.0  2013.0
# 3       1.0      4.0         6.0    1.0   6.0  2013.0
# 4       2.0      8.0         8.0    1.0  11.0  2013.0

# %%
match_totals.head()
# Out:
#    Result  Margin         BR  Toss  Bat  Opposition  Ground  Match_ID  \
# 0     6.0   160.0  52.000182   1.0  1.0         5.0    57.0       0.0
# 1     3.0   160.0  52.728414   2.0  2.0        11.0    57.0       0.0
# 2     3.0     3.0  20.689046   1.0  2.0         5.0    29.0       1.0
# 3     6.0     3.0  21.548194   2.0  1.0        11.0    29.0       1.0
# 4     3.0    10.0  19.527705   1.0  2.0         1.0    63.0       2.0
#
#    Country  Country_ID  Month   Day    year
# 0      6.0         7.0    1.0   3.0  2013.0
# 1      4.0         6.0    1.0   3.0  2013.0
# 2      6.0         7.0    1.0   6.0  2013.0
# 3      4.0         6.0    1.0   6.0  2013.0
# 4      8.0         8.0    1.0  11.0  2013.0

# %%
wc_player.head()
# Out:
#    Player      ID  Country
# 0      42  352048        0
# 1     118  793463        0
# 2       5  440963        0
# 3      13  320652        0
# 4      30  516561        0

# %%
match_results.isnull().sum()
# Out:
# Score         0
# Overs         0
# RPO           0
# Target        0
# Inns          0
# Result        0
# Opposition    0
# Ground        0
# Match_ID      0
# Country       0
# Country_ID    0
# Month         0
# Day           0
# year          0
# dtype: int64

# %%
match_totals.isnull().sum()
# Out:
# Result        0
# Margin        0
# BR            0
# Toss          0
# Bat           0
# Opposition    0
# Ground        0
# Match_ID      0
# Country       0
# Country_ID    0
# Month         0
# Day           0
# year          0
# dtype: int64

# %%
imputer = IterativeImputer()
df_list2 = [match_results,match_totals]

def treat_missing_value(df_list2):
    for i in range(len(df_list2)):
        df_imputed = imputer.fit_transform(df_list2[i])
        df_list2[i] = pd.DataFrame(df_imputed, columns=df_list2[i].columns)
        print("DataFrame", i, "after imputation:")
        print(df_list2[i].isnull().sum()) #Lets Check the Values treated well or not
        print("-------------------------")

# %%
treat_missing_value(df_list2)
# Out:
# DataFrame 0 after imputation:
# Score         0
# Overs         0
# RPO           0
# Target        0
# Inns          0
# Result        0
# Opposition    0
# Ground        0
# Match_ID      0
# Country       0
# Country_ID    0
# Month         0
# Day           0
# year          0
# dtype: int64
# -------------------------
# DataFrame 1 after imputation:
# Result        0
# Margin        0
# BR            0
# Toss          0
# Bat           0
# Opposition    0
# Ground        0
# Match_ID      0
# Country       0
# Country_ID    0
# Month         0
# Day           0
# year          0
# dtype: int64
# -------------------------

# %%
match_totals=df_list2[0]
match_results=df_list2[1]

# %%
bats_df
# Out:
#        Bat1  Runs   BF    SR  4s  6s  Opposition  Ground  Match_ID  Batsman  \
# 0       319     0    0     0   0   0           9      92       759      113
# 1       319     0    0     0   0   0           9      78       761      113
# 2       319     0    0     0   0   0           9      37       762      113
# 3       319     0    0     0   0   0           4      38       763      113
# 4       319     0    0     0   0   0           9      38       764      113
# ...     ...   ...  ...   ...  ..  ..         ...     ...       ...      ...
# 11144   203   121  121  1409  22   2          10      36      1809       42
# 11145   167   103  119   969   1   1          10      36      1810       42
# 11146     2     2  141   330   1   1          10      36      1817       42
# 11147   319     0    0     0   0   0          16      46      1834       42
# 11148   320     0    0     0   0   0          10       8      1842       42
#
#        Player_ID  Month  Day  year
# 0          49619     12   18  2009
# 1          49619     12   24  2009
# 2          49619     12   27  2009
# 3          49619      1    4  2010
# 4          49619      1    5  2010
# ...          ...    ...  ...   ...
# 11144     352048      2   28  2019
# 11145     352048      3    2  2019
# 11146     352048      3    8  2019
# 11147     352048      5   10  2019
# 11148     352048      5   19  2019
#
# [11149 rows x 14 columns]

# %%
bowl_df
# Out:
#        Overs  Mdns  Runs  Wkts  Econ  Ave  SR  Opposition  Ground  Match_ID  \
# 0         49     1    59     1   412    0   0           9      92       759
# 1         12     1    57     3   316  103  77           9      78       761
# 2          0     0     0     0     0    0   0           9      37       762
# 3         55     2    66     3   406  120  70           4      38       763
# 4         49     2    49     1   349    0   0           9      38       764
# ...      ...   ...   ...   ...   ...  ...  ..         ...     ...       ...
# 11113     25     1    42     1    35    0   0           9      40      1758
# 11114     45     1    19     3   112    5  60          10      36      1809
# 11115      0     0     0     0     0    0   0          10      36      1810
# 11116     37     1    20     2   171   80  83          10      36      1817
# 11117     12     1    76     4   417   92  56          16      46      1834
#
#        Bowler  Player_ID  Month  Day  year
# 0         138      49619     12   18  2009
# 1         138      49619     12   24  2009
# 2         138      49619     12   27  2009
# 3         138      49619      1    4  2010
# 4         138      49619      1    5  2010
# ...       ...        ...    ...  ...   ...
# 11113      42     352048      9   25  2018
# 11114      42     352048      2   28  2019
# 11115      42     352048      3    2  2019
# 11116      42     352048      3    8  2019
# 11117      42     352048      5   10  2019
#
# [11118 rows x 15 columns]

# %%
ground_df
# Out:
#      Ground  Span  Mat  Won  Tied  NR  Runs  Wkts  Balls    Ave   RPO
# 0        23     4    4    4     0   0  2161    72   2297  30.01  5.64
# 1        26     6    4    4     0   0  1789    75   2331  23.85  4.60
# 2        55     6   15   15     0   0  7656   217   8482  35.28  5.41
# 3        76     2    2    2     0   0  1163    26   1200  44.73  5.81
# 4         0     6   10   10     0   0  4863   157   5645  30.97  5.16
# ..      ...   ...  ...  ...   ...  ..   ...   ...    ...    ...   ...
# 101      32    18    1    1     0   0   209    11    280  19.00  4.47
# 102      90    18    1    1     0   0   400    11    531  36.36  4.51
# 103      70    19    5    4     0   1  1864    67   2524  27.82  4.43
# 104     100    19    1    1     0   0   307    17    474  18.05  3.88
# 105       1    19    1    1     0   0   329    15    460  21.93  4.29
#
# [106 rows x 11 columns]

# %%
#Lets Create a master dataset and the build the model
# so first we are going to merge 2 dataset and then further
batsman_join_bowler=pd.merge(bats_df,bowl_df,on=['Match_ID','Player_ID','Opposition','Ground','Month','Day','year'], how='inner')
batsman_join_bowler
# Out:
#        Bat1  Runs_x   BF  SR_x  4s  6s  Opposition  Ground  Match_ID  Batsman  \
# 0       319       0    0     0   0   0           9      92       759      113
# 1       319       0    0     0   0   0           9      78       761      113
# 2       319       0    0     0   0   0           9      37       762      113
# 3       319       0    0     0   0   0           4      38       763      113
# 4       319       0    0     0   0   0           9      38       764      113
# ...     ...     ...  ...   ...  ..  ..         ...     ...       ...      ...
# 11113    99      57  104   826   2   1           9      40      1758       42
# 11114   203     121  121  1409  22   2          10      36      1809       42
# 11115   167     103  119   969   1   1          10      36      1810       42
# 11116     2       2  141   330   1   1          10      36      1817       42
# 11117   319       0    0     0   0   0          16      46      1834       42
#
#        ...  Day  year  Overs  Mdns  Runs_y  Wkts  Econ  Ave  SR_y  Bowler
# 0      ...   18  2009     49     1      59     1   412    0     0     138
# 1      ...   24  2009     12     1      57     3   316  103    77     138
# 2      ...   27  2009      0     0       0     0     0    0     0     138
# 3      ...    4  2010     55     2      66     3   406  120    70     138
# 4      ...    5  2010     49     2      49     1   349    0     0     138
# ...    ...  ...   ...    ...   ...     ...   ...   ...  ...   ...     ...
# 11113  ...   25  2018     25     1      42     1    35    0     0      42
# 11114  ...   28  2019     45     1      19     3   112    5    60      42
# 11115  ...    2  2019      0     0       0     0     0    0     0      42
# 11116  ...    8  2019     37     1      20     2   171   80    83      42
# 11117  ...   10  2019     12     1      76     4   417   92    56      42
#
# [11118 rows x 22 columns]

# %%
batsman_join_bowler.columns
# Out:
# Index(['Bat1', 'Runs_x', 'BF', 'SR_x', '4s', '6s', 'Opposition', 'Ground',
#        'Match_ID', 'Batsman', 'Player_ID', 'Month', 'Day', 'year', 'Overs',
#        'Mdns', 'Runs_y', 'Wkts', 'Econ', 'Ave', 'SR_y', 'Bowler'],
#       dtype='object')

# %%
bowl_df.columns
# Out:
# Index(['Overs', 'Mdns', 'Runs', 'Wkts', 'Econ', 'Ave', 'SR', 'Opposition',
#        'Ground', 'Match_ID', 'Bowler', 'Player_ID', 'Month', 'Day', 'year'],
#       dtype='object')

# %%
#Lets Join ground_df
batsman_join_bowler_GrondAvg=pd.merge(batsman_join_bowler,ground_df,on=['Ground'], how='inner')
batsman_join_bowler_GrondAvg
# Out:
#       Bat1  Runs_x   BF  SR_x  4s  6s  Opposition  Ground  Match_ID  Batsman  \
# 0      319       0    0     0   0   0           9      92       759      113
# 1       12       7   21  1757  24  10           9      92        84       20
# 2      217     128  104   240   3   1           9      92       391       20
# 3      184     111   81   572  20   1           9      92       759       11
# 4      319       0    0     0   0   0           9      92       927       25
# ...    ...     ...  ...   ...  ..  ..         ...     ...       ...      ...
# 9074   217     128  117  1780  22   2          10      36      1817      117
# 9075   180     109   84   389  13   9          10      36      1819      117
# 9076   203     121  121  1409  22   2          10      36      1809       42
# 9077   167     103  119   969   1   1          10      36      1810       42
# 9078     2       2  141   330   1   1          10      36      1817       42
#
#       ...  Span  Mat  Won  Tied  NR  Runs  Wkts_y  Balls  Ave_y   RPO
# 0     ...     6   16   14     0   2  6890     202   7508  34.10  5.50
# 1     ...     6   16   14     0   2  6890     202   7508  34.10  5.50
# 2     ...     6   16   14     0   2  6890     202   7508  34.10  5.50
# 3     ...     6   16   14     0   2  6890     202   7508  34.10  5.50
# 4     ...     6   16   14     0   2  6890     202   7508  34.10  5.50
# ...   ...   ...  ...  ...   ...  ..   ...     ...    ...    ...   ...
# 9074  ...     4    4    4     0   0  1664      56   1987  29.71  5.02
# 9075  ...     4    4    4     0   0  1664      56   1987  29.71  5.02
# 9076  ...     4    4    4     0   0  1664      56   1987  29.71  5.02
# 9077  ...     4    4    4     0   0  1664      56   1987  29.71  5.02
# 9078  ...     4    4    4     0   0  1664      56   1987  29.71  5.02
#
# [9079 rows x 32 columns]

# %%
batsman_join_bowler_GrondAvg.columns
# Out:
# Index(['Bat1', 'Runs_x', 'BF', 'SR_x', '4s', '6s', 'Opposition', 'Ground',
#        'Match_ID', 'Batsman', 'Player_ID', 'Month', 'Day', 'year', 'Overs',
#        'Mdns', 'Runs_y', 'Wkts_x', 'Econ', 'Ave_x', 'SR_y', 'Bowler', 'Span',
#        'Mat', 'Won', 'Tied', 'NR', 'Runs', 'Wkts_y', 'Balls', 'Ave_y', 'RPO'],
#       dtype='object')

# %%
match_results.columns
# Out:
# Index(['Result', 'Margin', 'BR', 'Toss', 'Bat', 'Opposition', 'Ground',
#        'Match_ID', 'Country', 'Country_ID', 'Month', 'Day', 'year'],
#       dtype='object')

# %%
match_totals.columns
# Out:
# Index(['Score', 'Overs', 'RPO', 'Target', 'Inns', 'Result', 'Opposition',
#        'Ground', 'Match_ID', 'Country', 'Country_ID', 'Month', 'Day', 'year'],
#       dtype='object')

# %%
#Lets Join match_results & match_totals
OD_Total_result=pd.merge(match_results,match_totals,on=['Ground','Country','Country_ID','Month','Day','year','Opposition'], how='inner')
OD_Total_result
# Out:
#       Result_x  Margin         BR  Toss  Bat  Opposition  Ground  Match_ID_x  \
# 0          6.0   160.0  52.000182   1.0  1.0         5.0    57.0         0.0
# 1          3.0   160.0  52.728414   2.0  2.0        11.0    57.0         0.0
# 2          3.0     3.0  20.689046   1.0  2.0         5.0    29.0         1.0
# 3          6.0     3.0  21.548194   2.0  1.0        11.0    29.0         1.0
# 4          3.0    10.0  19.527705   1.0  2.0         1.0    63.0         2.0
# ...        ...     ...        ...   ...  ...         ...     ...         ...
# 1291       3.0    99.0   3.000000   1.0  1.0         3.0    72.0       755.0
# 1292       6.0    99.0   3.000000   2.0  2.0        11.0    72.0       755.0
# 1293       0.0     0.0  32.327406   2.0  2.0         6.0     7.0       757.0
# 1294       0.0     0.0  29.815762   1.0  2.0         3.0    60.0       758.0
# 1295       0.0     0.0  31.063998   2.0  1.0        11.0    60.0       758.0
#
#       Country  Country_ID  Month   Day    year  Score  Overs    RPO  \
# 0         6.0         7.0    1.0   3.0  2013.0  404.0   48.3  165.0
# 1         4.0         6.0    1.0   3.0  2013.0  115.0   48.0   25.0
# 2         6.0         7.0    1.0   6.0  2013.0   93.0   48.5   18.0
# 3         4.0         6.0    1.0   6.0  2013.0  120.0   43.4   48.0
# 4         8.0         8.0    1.0  11.0  2013.0  199.0   40.0  146.0
# ...       ...         ...    ...   ...     ...    ...    ...    ...
# 1291      6.0         7.0    5.0  17.0  2019.0  750.0   50.0  309.0
# 1292      3.0         1.0    5.0  17.0  2019.0  753.0   49.3  315.0
# 1293      0.0        40.0    5.0  19.0  2019.0   27.0   33.0   38.0
# 1294      6.0         7.0    5.0  19.0  2019.0  187.0   31.5  249.0
# 1295      3.0         1.0    5.0  19.0  2019.0  767.0   50.0  322.0
#
#           Target  Inns  Result_y  Match_ID_y
# 0     241.723435   1.0       4.0         0.0
# 1     251.000000   2.0       1.0         0.0
# 2     168.000000   2.0       1.0         1.0
# 3     176.027214   1.0       4.0         1.0
# 4     306.000000   2.0       1.0         2.0
# ...          ...   ...       ...         ...
# 1291  382.947700   1.0       1.0       739.0
# 1292  341.000000   2.0       4.0       739.0
# 1293  211.000000   2.0       0.0       740.0
# 1294  352.000000   2.0       0.0       741.0
# 1295  406.462269   1.0       0.0       741.0
#
# [1296 rows x 20 columns]

# %%
#Lets Join batsman_join_bowler_GrondAvg & OD_Total_result
batsman_join_bowler_GrondAvg_OD=pd.merge(batsman_join_bowler_GrondAvg,OD_Total_result,on=['Ground','Month','Day','year'], how='inner')
batsman_join_bowler_GrondAvg_OD
# Out:
#       Bat1  Runs_x   BF  SR_x  4s  6s  Opposition_x  Ground  Match_ID  \
# 0      140      86   14   677   1   1            15       1      1225
# 1      140      86   14   677   1   1            15       1      1225
# 2        0       1  108     1   1   1            15       1      1225
# 3        0       1  108     1   1   1            15       1      1225
# 4      277     158  141     4   2   1            15       1      1225
# ...    ...     ...  ...   ...  ..  ..           ...     ...       ...
# 1039   191     115  131  1056   2   2            10      36      1819
# 1040   284     161   16  1375  22   9            10      36      1819
# 1041   284     161   16  1375  22   9            10      36      1819
# 1042   180     109   84   389  13   9            10      36      1819
# 1043   180     109   84   389  13   9            10      36      1819
#
#       Batsman  ...  Match_ID_x  Country  Country_ID  Score  Overs_y  RPO_y  \
# 0         113  ...       126.0      8.0         8.0  294.0     48.5  111.0
# 1         113  ...       126.0      6.0         7.0  298.0     41.1  196.0
# 2          80  ...       126.0      8.0         8.0  294.0     48.5  111.0
# 3          80  ...       126.0      6.0         7.0  298.0     41.1  196.0
# 4          78  ...       126.0      8.0         8.0  294.0     48.5  111.0
# ...       ...  ...         ...      ...         ...    ...      ...    ...
# 1039       99  ...       733.0      7.0         3.0  734.0     50.0  297.0
# 1040       13  ...       733.0      8.0         8.0   29.0     24.0  154.0
# 1041       13  ...       733.0      7.0         3.0  734.0     50.0  297.0
# 1042      117  ...       733.0      8.0         8.0   29.0     24.0  154.0
# 1043      117  ...       733.0      7.0         3.0  734.0     50.0  297.0
#
#           Target  Inns  Result_y  Match_ID_y
# 0     297.147940   1.0       1.0       123.0
# 1     226.000000   2.0       4.0       123.0
# 2     297.147940   1.0       1.0       123.0
# 3     226.000000   2.0       4.0       123.0
# 4     297.147940   1.0       1.0       123.0
# ...          ...   ...       ...         ...
# 1039  298.485314   1.0       4.0       719.0
# 1040  193.000000   2.0       1.0       719.0
# 1041  298.485314   1.0       4.0       719.0
# 1042  193.000000   2.0       1.0       719.0
# 1043  298.485314   1.0       4.0       719.0
#
# [1044 rows x 48 columns]

# %%
batsman_join_bowler_GrondAvg_OD.columns
# Out:
# Index(['Bat1', 'Runs_x', 'BF', 'SR_x', '4s', '6s', 'Opposition_x', 'Ground',
#        'Match_ID', 'Batsman', 'Player_ID', 'Month', 'Day', 'year', 'Overs_x',
#        'Mdns', 'Runs_y', 'Wkts_x', 'Econ', 'Ave_x', 'SR_y', 'Bowler', 'Span',
#        'Mat', 'Won', 'Tied', 'NR', 'Runs', 'Wkts_y', 'Balls', 'Ave_y', 'RPO_x',
#        'Result_x', 'Margin', 'BR', 'Toss', 'Bat', 'Opposition_y', 'Match_ID_x',
#        'Country', 'Country_ID', 'Score', 'Overs_y', 'RPO_y', 'Target', 'Inns',
#        'Result_y', 'Match_ID_y'],
#       dtype='object')

# %%
wc_player.head()
# Out:
#    Player      ID  Country
# 0      42  352048        0
# 1     118  793463        0
# 2       5  440963        0
# 3      13  320652        0
# 4      30  516561        0

# %%
#Lets Create a master dataset and the build the model
# so first we are going to merge 2 dataset and then further
batsman_join_bowler=pd.merge(bats_df,bowl_df,on=['Match_ID','Player_ID','Opposition','Ground','Month','Day','year'], how='inner')
batsman_join_bowler
# Out:
#        Bat1  Runs_x   BF  SR_x  4s  6s  Opposition  Ground  Match_ID  Batsman  \
# 0       319       0    0     0   0   0           9      92       759      113
# 1       319       0    0     0   0   0           9      78       761      113
# 2       319       0    0     0   0   0           9      37       762      113
# 3       319       0    0     0   0   0           4      38       763      113
# 4       319       0    0     0   0   0           9      38       764      113
# ...     ...     ...  ...   ...  ..  ..         ...     ...       ...      ...
# 11113    99      57  104   826   2   1           9      40      1758       42
# 11114   203     121  121  1409  22   2          10      36      1809       42
# 11115   167     103  119   969   1   1          10      36      1810       42
# 11116     2       2  141   330   1   1          10      36      1817       42
# 11117   319       0    0     0   0   0          16      46      1834       42
#
#        ...  Day  year  Overs  Mdns  Runs_y  Wkts  Econ  Ave  SR_y  Bowler
# 0      ...   18  2009     49     1      59     1   412    0     0     138
# 1      ...   24  2009     12     1      57     3   316  103    77     138
# 2      ...   27  2009      0     0       0     0     0    0     0     138
# 3      ...    4  2010     55     2      66     3   406  120    70     138
# 4      ...    5  2010     49     2      49     1   349    0     0     138
# ...    ...  ...   ...    ...   ...     ...   ...   ...  ...   ...     ...
# 11113  ...   25  2018     25     1      42     1    35    0     0      42
# 11114  ...   28  2019     45     1      19     3   112    5    60      42
# 11115  ...    2  2019      0     0       0     0     0    0     0      42
# 11116  ...    8  2019     37     1      20     2   171   80    83      42
# 11117  ...   10  2019     12     1      76     4   417   92    56      42
#
# [11118 rows x 22 columns]

# %%
batsman_join_bowler.columns
# Out:
# Index(['Bat1', 'Runs_x', 'BF', 'SR_x', '4s', '6s', 'Opposition', 'Ground',
#        'Match_ID', 'Batsman', 'Player_ID', 'Month', 'Day', 'year', 'Overs',
#        'Mdns', 'Runs_y', 'Wkts', 'Econ', 'Ave', 'SR_y', 'Bowler'],
#       dtype='object')

# %%
bowl_df.columns
# Out:
# Index(['Overs', 'Mdns', 'Runs', 'Wkts', 'Econ', 'Ave', 'SR', 'Opposition',
#        'Ground', 'Match_ID', 'Bowler', 'Player_ID', 'Month', 'Day', 'year'],
#       dtype='object')

# %%
#Lets Join ground_df
batsman_join_bowler_GrondAvg=pd.merge(batsman_join_bowler,ground_df,on=['Ground'], how='inner')
batsman_join_bowler_GrondAvg
# Out:
#       Bat1  Runs_x   BF  SR_x  4s  6s  Opposition  Ground  Match_ID  Batsman  \
# 0      319       0    0     0   0   0           9      92       759      113
# 1       12       7   21  1757  24  10           9      92        84       20
# 2      217     128  104   240   3   1           9      92       391       20
# 3      184     111   81   572  20   1           9      92       759       11
# 4      319       0    0     0   0   0           9      92       927       25
# ...    ...     ...  ...   ...  ..  ..         ...     ...       ...      ...
# 9074   217     128  117  1780  22   2          10      36      1817      117
# 9075   180     109   84   389  13   9          10      36      1819      117
# 9076   203     121  121  1409  22   2          10      36      1809       42
# 9077   167     103  119   969   1   1          10      36      1810       42
# 9078     2       2  141   330   1   1          10      36      1817       42
#
#       ...  Span  Mat  Won  Tied  NR  Runs  Wkts_y  Balls  Ave_y   RPO
# 0     ...     6   16   14     0   2  6890     202   7508  34.10  5.50
# 1     ...     6   16   14     0   2  6890     202   7508  34.10  5.50
# 2     ...     6   16   14     0   2  6890     202   7508  34.10  5.50
# 3     ...     6   16   14     0   2  6890     202   7508  34.10  5.50
# 4     ...     6   16   14     0   2  6890     202   7508  34.10  5.50
# ...   ...   ...  ...  ...   ...  ..   ...     ...    ...    ...   ...
# 9074  ...     4    4    4     0   0  1664      56   1987  29.71  5.02
# 9075  ...     4    4    4     0   0  1664      56   1987  29.71  5.02
# 9076  ...     4    4    4     0   0  1664      56   1987  29.71  5.02
# 9077  ...     4    4    4     0   0  1664      56   1987  29.71  5.02
# 9078  ...     4    4    4     0   0  1664      56   1987  29.71  5.02
#
# [9079 rows x 32 columns]

# %%
batsman_join_bowler_GrondAvg.columns
# Out:
# Index(['Bat1', 'Runs_x', 'BF', 'SR_x', '4s', '6s', 'Opposition', 'Ground',
#        'Match_ID', 'Batsman', 'Player_ID', 'Month', 'Day', 'year', 'Overs',
#        'Mdns', 'Runs_y', 'Wkts_x', 'Econ', 'Ave_x', 'SR_y', 'Bowler', 'Span',
#        'Mat', 'Won', 'Tied', 'NR', 'Runs', 'Wkts_y', 'Balls', 'Ave_y', 'RPO'],
#       dtype='object')

# %%
match_results.columns
# Out:
# Index(['Result', 'Margin', 'BR', 'Toss', 'Bat', 'Opposition', 'Ground',
#        'Match_ID', 'Country', 'Country_ID', 'Month', 'Day', 'year'],
#       dtype='object')

# %%
match_totals.columns
# Out:
# Index(['Score', 'Overs', 'RPO', 'Target', 'Inns', 'Result', 'Opposition',
#        'Ground', 'Match_ID', 'Country', 'Country_ID', 'Month', 'Day', 'year'],
#       dtype='object')

# %%
#Lets Join match_results & match_totals
OD_Total_result=pd.merge(match_results,match_totals,on=['Ground','Country','Country_ID','Month','Day','year','Opposition'], how='inner')
OD_Total_result
# Out:
#       Result_x  Margin         BR  Toss  Bat  Opposition  Ground  Match_ID_x  \
# 0          6.0   160.0  52.000182   1.0  1.0         5.0    57.0         0.0
# 1          3.0   160.0  52.728414   2.0  2.0        11.0    57.0         0.0
# 2          3.0     3.0  20.689046   1.0  2.0         5.0    29.0         1.0
# 3          6.0     3.0  21.548194   2.0  1.0        11.0    29.0         1.0
# 4          3.0    10.0  19.527705   1.0  2.0         1.0    63.0         2.0
# ...        ...     ...        ...   ...  ...         ...     ...         ...
# 1291       3.0    99.0   3.000000   1.0  1.0         3.0    72.0       755.0
# 1292       6.0    99.0   3.000000   2.0  2.0        11.0    72.0       755.0
# 1293       0.0     0.0  32.327406   2.0  2.0         6.0     7.0       757.0
# 1294       0.0     0.0  29.815762   1.0  2.0         3.0    60.0       758.0
# 1295       0.0     0.0  31.063998   2.0  1.0        11.0    60.0       758.0
#
#       Country  Country_ID  Month   Day    year  Score  Overs    RPO  \
# 0         6.0         7.0    1.0   3.0  2013.0  404.0   48.3  165.0
# 1         4.0         6.0    1.0   3.0  2013.0  115.0   48.0   25.0
# 2         6.0         7.0    1.0   6.0  2013.0   93.0   48.5   18.0
# 3         4.0         6.0    1.0   6.0  2013.0  120.0   43.4   48.0
# 4         8.0         8.0    1.0  11.0  2013.0  199.0   40.0  146.0
# ...       ...         ...    ...   ...     ...    ...    ...    ...
# 1291      6.0         7.0    5.0  17.0  2019.0  750.0   50.0  309.0
# 1292      3.0         1.0    5.0  17.0  2019.0  753.0   49.3  315.0
# 1293      0.0        40.0    5.0  19.0  2019.0   27.0   33.0   38.0
# 1294      6.0         7.0    5.0  19.0  2019.0  187.0   31.5  249.0
# 1295      3.0         1.0    5.0  19.0  2019.0  767.0   50.0  322.0
#
#           Target  Inns  Result_y  Match_ID_y
# 0     241.723435   1.0       4.0         0.0
# 1     251.000000   2.0       1.0         0.0
# 2     168.000000   2.0       1.0         1.0
# 3     176.027214   1.0       4.0         1.0
# 4     306.000000   2.0       1.0         2.0
# ...          ...   ...       ...         ...
# 1291  382.947700   1.0       1.0       739.0
# 1292  341.000000   2.0       4.0       739.0
# 1293  211.000000   2.0       0.0       740.0
# 1294  352.000000   2.0       0.0       741.0
# 1295  406.462269   1.0       0.0       741.0
#
# [1296 rows x 20 columns]

# %%
#Lets Join batsman_join_bowler_GrondAvg & OD_Total_result
batsman_join_bowler_GrondAvg_OD=pd.merge(batsman_join_bowler_GrondAvg,OD_Total_result,on=['Ground','Month','Day','year'], how='inner')
batsman_join_bowler_GrondAvg_OD
# Out:
#       Bat1  Runs_x   BF  SR_x  4s  6s  Opposition_x  Ground  Match_ID  \
# 0      140      86   14   677   1   1            15       1      1225
# 1      140      86   14   677   1   1            15       1      1225
# 2        0       1  108     1   1   1            15       1      1225
# 3        0       1  108     1   1   1            15       1      1225
# 4      277     158  141     4   2   1            15       1      1225
# ...    ...     ...  ...   ...  ..  ..           ...     ...       ...
# 1039   191     115  131  1056   2   2            10      36      1819
# 1040   284     161   16  1375  22   9            10      36      1819
# 1041   284     161   16  1375  22   9            10      36      1819
# 1042   180     109   84   389  13   9            10      36      1819
# 1043   180     109   84   389  13   9            10      36      1819
#
#       Batsman  ...  Match_ID_x  Country  Country_ID  Score  Overs_y  RPO_y  \
# 0         113  ...       126.0      8.0         8.0  294.0     48.5  111.0
# 1         113  ...       126.0      6.0         7.0  298.0     41.1  196.0
# 2          80  ...       126.0      8.0         8.0  294.0     48.5  111.0
# 3          80  ...       126.0      6.0         7.0  298.0     41.1  196.0
# 4          78  ...       126.0      8.0         8.0  294.0     48.5  111.0
# ...       ...  ...         ...      ...         ...    ...      ...    ...
# 1039       99  ...       733.0      7.0         3.0  734.0     50.0  297.0
# 1040       13  ...       733.0      8.0         8.0   29.0     24.0  154.0
# 1041       13  ...       733.0      7.0         3.0  734.0     50.0  297.0
# 1042      117  ...       733.0      8.0         8.0   29.0     24.0  154.0
# 1043      117  ...       733.0      7.0         3.0  734.0     50.0  297.0
#
#           Target  Inns  Result_y  Match_ID_y
# 0     297.147940   1.0       1.0       123.0
# 1     226.000000   2.0       4.0       123.0
# 2     297.147940   1.0       1.0       123.0
# 3     226.000000   2.0       4.0       123.0
# 4     297.147940   1.0       1.0       123.0
# ...          ...   ...       ...         ...
# 1039  298.485314   1.0       4.0       719.0
# 1040  193.000000   2.0       1.0       719.0
# 1041  298.485314   1.0       4.0       719.0
# 1042  193.000000   2.0       1.0       719.0
# 1043  298.485314   1.0       4.0       719.0
#
# [1044 rows x 48 columns]

# %%
batsman_join_bowler_GrondAvg_OD.columns
# Out:
# Index(['Bat1', 'Runs_x', 'BF', 'SR_x', '4s', '6s', 'Opposition_x', 'Ground',
#        'Match_ID', 'Batsman', 'Player_ID', 'Month', 'Day', 'year', 'Overs_x',
#        'Mdns', 'Runs_y', 'Wkts_x', 'Econ', 'Ave_x', 'SR_y', 'Bowler', 'Span',
#        'Mat', 'Won', 'Tied', 'NR', 'Runs', 'Wkts_y', 'Balls', 'Ave_y', 'RPO_x',
#        'Result_x', 'Margin', 'BR', 'Toss', 'Bat', 'Opposition_y', 'Match_ID_x',
#        'Country', 'Country_ID', 'Score', 'Overs_y', 'RPO_y', 'Target', 'Inns',
#        'Result_y', 'Match_ID_y'],
#       dtype='object')

# %%
wc_player=wc_player.rename(columns={'ID':'Player_ID'})

# %%
wc_player.columns
# Out:
# Index(['Player', 'Player_ID', 'Country'], dtype='object')

# %%
#Lets Join batsman_join_bowler_GrondAvg_OD & wc_player
master_after_join=pd.merge(batsman_join_bowler_GrondAvg_OD,wc_player,on=['Player_ID','Country'], how='inner')
master_after_join
# Out:
#      Bat1  Runs_x   BF  SR_x  4s  6s  Opposition_x  Ground  Match_ID  Batsman  \
# 0       0       1  108     1   1   1            15       1      1225       80
# 1       0       1    2     1   1   1            15       1      1227       80
# 2       2       2  130   518   1   1             0       1      1750       80
# 3     319       0    0     0   0   0             3       2      1106       80
# 4     277     158  141     4   2   1            15       1      1225       78
# ..    ...     ...  ...   ...  ..  ..           ...     ...       ...      ...
# 505   319       0    0     0   0   0            13       5      1590        9
# 506   154      96  109   946  18   1            17       5      1590       93
# 507     5       3  130   535  13   1            15       5      1485       93
# 508   255     147   74   849   1   1             3       5      1574       93
# 509   180     109   96  1782   2   9             3       5      1486       93
#
#      ...  Country  Country_ID  Score  Overs_y  RPO_y      Target  Inns  \
# 0    ...      8.0         8.0  294.0     48.5  111.0  297.147940   1.0
# 1    ...      8.0         8.0  335.0     49.4  124.0  233.000000   2.0
# 2    ...      8.0         8.0   98.0     41.2   48.0  250.000000   2.0
# 3    ...      8.0         8.0  133.0     40.1   81.0  171.000000   2.0
# 4    ...      8.0         8.0  294.0     48.5  111.0  297.147940   1.0
# ..   ...      ...         ...    ...      ...    ...         ...   ...
# 505  ...      7.0         3.0   76.0     32.2  114.0  150.000000   2.0
# 506  ...      5.0         5.0   75.0     41.1   36.0  238.692029   1.0
# 507  ...      5.0         5.0  476.0     42.4  262.0  263.000000   2.0
# 508  ...      5.0         5.0  575.0     50.0  219.0  268.556106   1.0
# 509  ...      5.0         5.0  659.0     50.0  256.0  282.867715   1.0
#
#      Result_y  Match_ID_y  Player
# 0         1.0       123.0      80
# 1         4.0       125.0      80
# 2         1.0       648.0      80
# 3         4.0         4.0      80
# 4         1.0       123.0      78
# ..        ...         ...     ...
# 505       4.0       488.0       9
# 506       1.0       488.0      94
# 507       4.0       383.0      94
# 508       4.0       472.0      94
# 509       4.0       384.0      94
#
# [510 rows x 49 columns]

# %%
# Calculate Batting Average for each player
master_after_join['Batting Average'] = master_after_join['Bat1'] / master_after_join['Inns']

# %%
# Display the Batting Average for each player
print(master_after_join[['Player', 'Batting Average']])
# Out:
#      Player  Batting Average
# 0        80              0.0
# 1        80              0.0
# 2        80              1.0
# 3        80            159.5
# 4        78            277.0
# ..      ...              ...
# 505       9            159.5
# 506      94            154.0
# 507      94              2.5
# 508      94            255.0
# 509      94            180.0
#
# [510 rows x 2 columns]

# %%
# Calculate Bowling Average for each player
master_after_join['Bowling Average'] = master_after_join['Runs_y'] / master_after_join['Wkts_y']

# Display the Bowling Average for each player
print(master_after_join[['Player', 'Bowling Average']])
# Out:
#      Player  Bowling Average
# 0        80         2.733333
# 1        80         3.933333
# 2        80         4.600000
# 3        80         0.941176
# 4        78         0.000000
# ..      ...              ...
# 505       9         0.729167
# 506      94         1.979167
# 507      94         1.208333
# 508      94         0.937500
# 509      94         0.020833
#
# [510 rows x 2 columns]

# %%
# Filter out rows with zero or missing values in 'BF'
master_after_join = master_after_join[master_after_join['BF'] > 0]

# %%
master_after_join.head(5)
# Out:
#    Bat1  Runs_x   BF  SR_x  4s  6s  Opposition_x  Ground  Match_ID  Batsman  \
# 0     0       1  108     1   1   1            15       1      1225       80
# 1     0       1    2     1   1   1            15       1      1227       80
# 2     2       2  130   518   1   1             0       1      1750       80
# 4   277     158  141     4   2   1            15       1      1225       78
# 5   205     122   99   256  18  11            15       1      1227       78
#
#    ...  Score  Overs_y  RPO_y     Target  Inns  Result_y  Match_ID_y  Player  \
# 0  ...  294.0     48.5  111.0  297.14794   1.0       1.0       123.0      80
# 1  ...  335.0     49.4  124.0  233.00000   2.0       4.0       125.0      80
# 2  ...   98.0     41.2   48.0  250.00000   2.0       1.0       648.0      80
# 4  ...  294.0     48.5  111.0  297.14794   1.0       1.0       123.0      78
# 5  ...  335.0     49.4  124.0  233.00000   2.0       4.0       125.0      78
#
#    Batting Average  Bowling Average
# 0              0.0         2.733333
# 1              0.0         3.933333
# 2              1.0         4.600000
# 4            277.0         0.000000
# 5            102.5         0.000000
#
# [5 rows x 51 columns]

# %%
# Calculate Strike Rate (Batting) for each player
master_after_join['Strike Rate (Batting)'] = (master_after_join['Bat1'] / master_after_join['BF']) * 100

# Display the Strike Rate (Batting) for each player
print(master_after_join[['Player', 'Strike Rate (Batting)']])
# Out:
#      Player  Strike Rate (Batting)
# 0        80               0.000000
# 1        80               0.000000
# 2        80               1.538462
# 4        78             196.453901
# 5        78             207.070707
# ..      ...                    ...
# 502      57             200.970874
# 506      94             141.284404
# 507      94               3.846154
# 508      94             344.594595
# 509      94             187.500000
#
# [444 rows x 2 columns]

# %%
# Calculate Economy Rate (Bowling) for each player
master_after_join['Economy Rate (Bowling)'] = (master_after_join['Runs_y'] / master_after_join['Overs_y'])

# Display the Economy Rate (Bowling) for each player
print(master_after_join[['Player', 'Economy Rate (Bowling)']])
# Out:
#      Player  Economy Rate (Bowling)
# 0        80                0.845361
# 1        80                1.194332
# 2        80                1.674757
# 4        78                0.000000
# 5        78                0.000000
# ..      ...                     ...
# 502      57                1.000000
# 506      94                2.311436
# 507      94                1.367925
# 508      94                0.900000
# 509      94                0.020000
#
# [444 rows x 2 columns]

# %%
# Calculate the total Maiden Overs for each player
master_after_join['Maiden Overs Total'] = master_after_join['Mdns'].sum()

# Display the total Maiden Overs for each player
print(master_after_join[['Player', 'Maiden Overs Total']])
# Out:
#      Player  Maiden Overs Total
# 0        80                 262
# 1        80                 262
# 2        80                 262
# 4        78                 262
# 5        78                 262
# ..      ...                 ...
# 502      57                 262
# 506      94                 262
# 507      94                 262
# 508      94                 262
# 509      94                 262
#
# [444 rows x 2 columns]

# %%
# Step 1: Choose relevant performance metrics
batting_average = master_after_join['Batting Average']
bowling_average = master_after_join['Bowling Average']
strike_rate_batting = master_after_join['Strike Rate (Batting)']
economy_rate_bowling = master_after_join['Economy Rate (Bowling)']
maiden_overs = master_after_join['Maiden Overs Total']

#Step 2: Normalize the selected performance metrics
# You can use Min-Max Scaling or Z-score normalization
def min_max_scaling(x):
    return (x - x.min()) / (x.max() - x.min())

normalized_batting_average = min_max_scaling(batting_average)
normalized_bowling_average = min_max_scaling(bowling_average)
normalized_strike_rate_batting = min_max_scaling(strike_rate_batting)
normalized_economy_rate_bowling = min_max_scaling(economy_rate_bowling)
# normalized_maiden_overs = min_max_scaling(maiden_overs) we are not using this its giving NAN

# Step 3: Assign weights to each performance metric
batting_weight = 0.3
bowling_weight = 0.25
strike_rate_weight = 0.2
economy_rate_weight = 0.25


# Step 4: Calculate the composite performance score for each player
master_after_join['Player Performance Score'] = (
    batting_weight * normalized_batting_average +
    bowling_weight * normalized_bowling_average +
    strike_rate_weight * normalized_strike_rate_batting +
    economy_rate_weight * normalized_economy_rate_bowling )

# Step 5: Display the Player Performance Score for each player
print(master_after_join[['Player', 'Player Performance Score']])
# Out:
#      Player  Player Performance Score
# 0        80                  0.179688
# 1        80                  0.256694
# 2        80                  0.324796
# 4        78                  0.267204
# 5        78                  0.102335
# ..      ...                       ...
# 502      57                  0.327119
# 506      94                  0.423807
# 507      94                  0.166335
# 508      94                  0.363639
# 509      94                  0.177696
#
# [444 rows x 2 columns]

# %%
master_after_join.shape
# Out:
# (444, 55)

# %%
master_after_join.columns
# Out:
# Index(['Bat1', 'Runs_x', 'BF', 'SR_x', '4s', '6s', 'Opposition_x', 'Ground',
#        'Match_ID', 'Batsman', 'Player_ID', 'Month', 'Day', 'year', 'Overs_x',
#        'Mdns', 'Runs_y', 'Wkts_x', 'Econ', 'Ave_x', 'SR_y', 'Bowler', 'Span',
#        'Mat', 'Won', 'Tied', 'NR', 'Runs', 'Wkts_y', 'Balls', 'Ave_y', 'RPO_x',
#        'Result_x', 'Margin', 'BR', 'Toss', 'Bat', 'Opposition_y', 'Match_ID_x',
#        'Country', 'Country_ID', 'Score', 'Overs_y', 'RPO_y', 'Target', 'Inns',
#        'Result_y', 'Match_ID_y', 'Player', 'Batting Average',
#        'Bowling Average', 'Strike Rate (Batting)', 'Economy Rate (Bowling)',
#        'Maiden Overs Total', 'Player Performance Score'],
#       dtype='object')

# %%
#Let's see the how data is distributed or Graphical analysis of all features
plt.figure(figsize=(15,20))
plotnumber=1
for column in master_after_join:
    if plotnumber<=60:
        ax=plt.subplot(10,6,plotnumber)
        sns.histplot(master_after_join[column])
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
# From above distribution we can see there are skewed data avilabe so lets check again by using skew method
master_after_join.skew()
# Out:
# Bat1                       -0.233887
# Runs_x                     -0.346075
# BF                         -0.445824
# SR_x                       -0.039165
# 4s                          0.578048
# 6s                          2.952126
# Opposition_x               -0.516344
# Ground                      0.970068
# Match_ID                   -0.326713
# Batsman                    -0.105322
# Player_ID                   0.979422
# Month                      -0.134240
# Day                        -0.024541
# year                       -0.322862
# Overs_x                     1.262778
# Mdns                        1.473151
# Runs_y                      1.019444
# Wkts_x                      1.420556
# Econ                        0.740863
# Ave_x                       1.770862
# SR_y                        1.372929
# Bowler                     -0.097655
# Span                       -2.101193
# Mat                         3.289249
# Won                         3.289249
# Tied                        0.000000
# NR                          0.000000
# Runs                        2.546417
# Wkts_y                      2.866807
# Balls                       2.933363
# Ave_y                       3.219416
# RPO_x                       1.697543
# Result_x                   -0.044760
# Margin                     -0.995123
# BR                          1.052424
# Toss                       -0.126806
# Bat                         0.218229
# Opposition_y               -0.301409
# Match_ID_x                 -0.337863
# Country                    -0.195242
# Country_ID                  2.054187
# Score                       0.291136
# Overs_y                    -2.122394
# RPO_y                       0.256769
# Target                      0.058698
# Inns                        0.218229
# Result_y                   -0.044760
# Match_ID_y                 -0.326713
# Player                     -0.085164
# Batting Average             0.423427
# Bowling Average             1.558220
# Strike Rate (Batting)       5.879068
# Economy Rate (Bowling)      1.403963
# Maiden Overs Total          0.000000
# Player Performance Score    0.489816
# dtype: float64

# %%
master_after_join.columns
# Out:
# Index(['Bat1', 'Runs_x', 'BF', 'SR_x', '4s', '6s', 'Opposition_x', 'Ground',
#        'Match_ID', 'Batsman', 'Player_ID', 'Month', 'Day', 'year', 'Overs_x',
#        'Mdns', 'Runs_y', 'Wkts_x', 'Econ', 'Ave_x', 'SR_y', 'Bowler', 'Span',
#        'Mat', 'Won', 'Tied', 'NR', 'Runs', 'Wkts_y', 'Balls', 'Ave_y', 'RPO_x',
#        'Result_x', 'Margin', 'BR', 'Toss', 'Bat', 'Opposition_y', 'Match_ID_x',
#        'Country', 'Country_ID', 'Score', 'Overs_y', 'RPO_y', 'Target', 'Inns',
#        'Result_y', 'Match_ID_y', 'Player', 'Batting Average',
#        'Bowling Average', 'Strike Rate (Batting)', 'Economy Rate (Bowling)',
#        'Maiden Overs Total', 'Player Performance Score'],
#       dtype='object')

# %%
# Lets Seaprate the skewed columns or featres based on above thumb rule
master_after_join.skew()[(master_after_join.skew() >= 0.5) & (master_after_join.skew() >= -0.5)]
# Out:
# 4s                        0.578048
# 6s                        2.952126
# Ground                    0.970068
# Player_ID                 0.979422
# Overs_x                   1.262778
# Mdns                      1.473151
# Runs_y                    1.019444
# Wkts_x                    1.420556
# Econ                      0.740863
# Ave_x                     1.770862
# SR_y                      1.372929
# Mat                       3.289249
# Won                       3.289249
# Runs                      2.546417
# Wkts_y                    2.866807
# Balls                     2.933363
# Ave_y                     3.219416
# RPO_x                     1.697543
# BR                        1.052424
# Country_ID                2.054187
# Bowling Average           1.558220
# Strike Rate (Batting)     5.879068
# Economy Rate (Bowling)    1.403963
# dtype: float64

# %%
skew_col=['4s','6s','Ground','Player_ID','Overs_x','Mdns','Runs_y','Wkts_x','Econ','Ave_x','SR_y','Mat','Won','Runs', 'Wkts_y', 'Balls', 'Ave_y', 'RPO_x','BR','Country_ID','Bowling Average','Bowling Average','Economy Rate (Bowling)']
len(skew_col)
# Out:
# 23

# %%
# Now almost All skewness we removed so move further
#Let's check for the Outliers
plt.figure(figsize=(15,20))
plotnumber=1
for column in master_after_join:
    if plotnumber<=60:
        ax=plt.subplot(10,6,plotnumber)
        sns.boxplot(master_after_join[column])
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
# So from graph we can see the outlier are present in the some columns so lets remove them first
outliers_col=['Margin', 'BR','Overs_y','Target','Ground','Span','Strike Rate (Batting)','Player Performance Score']

# %%
# Remove the outliers by using Z score

z_score=zscore(master_after_join[outliers_col])
z_score_abs=np.abs(z_score)
filter_entry=(z_score_abs<3).all(axis=1)
master_after_join=master_after_join[filter_entry]
master_after_join.head()
# Out:
#    Bat1  Runs_x   BF  SR_x  4s  6s  Opposition_x  Ground  Match_ID  Batsman  \
# 0     0       1  108     1   1   1            15       1      1225       80
# 1     0       1    2     1   1   1            15       1      1227       80
# 2     2       2  130   518   1   1             0       1      1750       80
# 4   277     158  141     4   2   1            15       1      1225       78
# 5   205     122   99   256  18  11            15       1      1227       78
#
#    ...  Inns  Result_y  Match_ID_y  Player  Batting Average  Bowling Average  \
# 0  ...   1.0       1.0       123.0      80              0.0         2.733333
# 1  ...   2.0       4.0       125.0      80              0.0         3.933333
# 2  ...   2.0       1.0       648.0      80              1.0         4.600000
# 4  ...   1.0       1.0       123.0      78            277.0         0.000000
# 5  ...   2.0       4.0       125.0      78            102.5         0.000000
#
#    Strike Rate (Batting)  Economy Rate (Bowling)  Maiden Overs Total  \
# 0               0.000000                0.845361                 262
# 1               0.000000                1.194332                 262
# 2               1.538462                1.674757                 262
# 4             196.453901                0.000000                 262
# 5             207.070707                0.000000                 262
#
#    Player Performance Score
# 0                  0.179688
# 1                  0.256694
# 2                  0.324796
# 4                  0.267204
# 5                  0.102335
#
# [5 rows x 55 columns]

# %%
#Let's recheck for the Outliers
plt.figure(figsize=(15,20))
plotnumber=1
for column in master_after_join:
    if plotnumber<=60:
        ax=plt.subplot(10,6,plotnumber)
        sns.boxplot(master_after_join[column])
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
# Use 'Player Performance Score' as the target variable for the prediction model

x = master_after_join[['Bat1', 'Runs_x', 'BF', 'SR_x', '4s', '6s', 'Opposition_x', 'Ground',
          'Match_ID', 'Batsman', 'Player_ID', 'Month', 'Day', 'year', 'Overs_x',
          'Mdns', 'Runs_y', 'Wkts_x', 'Econ', 'Ave_x', 'SR_y', 'Bowler', 'Span',
          'Mat', 'Won', 'Tied', 'NR', 'Runs', 'Wkts_y', 'Balls', 'Ave_y', 'RPO_x',
          'Result_x', 'Margin', 'BR', 'Toss', 'Bat', 'Opposition_y', 'Match_ID_x',
          'Country', 'Country_ID', 'Score', 'Overs_y', 'RPO_y', 'Target', 'Inns',
          'Result_y', 'Match_ID_y']]

y = master_after_join['Player Performance Score']  # Target column

# %%
print(x.shape, y.shape)
# Out:
# (408, 48) (408,)

# %%
# data stadardization

scale=StandardScaler()
x_scaled=scale.fit_transform(x)

# %%
#check multicolinearity

vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif["featurs"]=x.columns
print(vif)
# Out:
#              vif       featurs
# 0   3.236749e+02          Bat1
# 1   3.272782e+02        Runs_x
# 2   1.320922e+00            BF
# 3   1.307263e+00          SR_x
# 4   1.475799e+00            4s
# 5   1.323690e+00            6s
# 6   9.955071e+01  Opposition_x
# 7            inf        Ground
# 8            inf      Match_ID
# 9   3.698207e+04       Batsman
# 10  1.314561e+00     Player_ID
# 11  2.534057e+01         Month
# 12  1.602917e+00           Day
# 13  5.465632e+02          year
# 14  2.529241e+00       Overs_x
# 15  3.353339e+00          Mdns
# 16  4.709796e+00        Runs_y
# 17  3.729181e+00        Wkts_x
# 18  4.896810e+00          Econ
# 19  5.506742e+00         Ave_x
# 20  5.854406e+00          SR_y
# 21  3.697764e+04        Bowler
# 22           inf          Span
# 23           inf           Mat
# 24           inf           Won
# 25           NaN          Tied
# 26           NaN            NR
# 27           inf          Runs
# 28           inf        Wkts_y
# 29           inf         Balls
# 30           inf         Ave_y
# 31           inf         RPO_x
# 32           inf      Result_x
# 33  1.701079e+00        Margin
# 34  2.170807e+00            BR
# 35  1.560636e+00          Toss
# 36           inf           Bat
# 37  1.000806e+02  Opposition_y
# 38  6.741544e+04    Match_ID_x
# 39  2.480307e+00       Country
# 40  2.155099e+00    Country_ID
# 41  1.079358e+02         Score
# 42  3.484388e+01       Overs_y
# 43  6.380615e+01         RPO_y
# 44  6.326810e+00        Target
# 45           inf          Inns
# 46           inf      Result_y
# 47           inf    Match_ID_y

# %%
pca=PCA()
pca.fit_transform(x_scaled)
# Out:
# array([[-1.71555826e+00,  4.05884099e-01,  1.85348981e+00, ...,
#          5.72856795e-17, -5.04114751e-16, -2.50954026e-16],
#        [-1.69510040e+00,  1.50837618e+00,  2.17212355e+00, ...,
#         -6.65465059e-16, -3.65142238e-16,  2.57640439e-16],
#        [-3.71259227e+00,  4.42855489e+00, -2.44666196e+00, ...,
#          6.11989145e-16,  1.01648397e-16,  1.05175944e-15],
#        ...,
#        [ 4.50361681e+00,  3.60959401e+00,  8.73510440e-01, ...,
#          2.51645284e-16, -8.20021303e-17, -9.88728611e-17],
#        [ 3.97481363e+00,  3.75290372e+00,  1.20113449e+00, ...,
#          2.51445754e-16, -5.84785703e-17, -4.53729531e-17],
#        [ 4.94412302e+00,  4.68456844e-01,  7.36605342e-01, ...,
#          9.39433347e-17,  1.15962217e-16,  2.88725254e-16]])

# %%
# Lets plot the PCA plot to select the best components
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("Principal Components")
plt.ylabel("Variance Covered")
plt.title("PCA Plot")
# Out:
# Text(0.5, 1.0, 'PCA Plot')

# %%
pca=PCA(n_components=19)
pca_x=pca.fit_transform(x_scaled)
pca_x=pd.DataFrame(pca_x,columns=['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13','PC14','PC15','PC16','PC17','PC18','PC19'])
pca_x
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0   -1.715558  0.405884  1.853490  4.041821  0.450206 -2.955397  0.621476
# 1   -1.695100  1.508376  2.172124  4.024685 -0.967734 -2.800127 -2.523633
# 2   -3.712592  4.428555 -2.446662  1.454384 -0.750505 -0.348771 -0.759009
# 3   -0.978327 -2.724740  1.068914  2.708875 -1.417543 -0.832131  1.534131
# 4   -0.425902 -3.345142  0.814003  2.180715 -3.359272 -1.043728 -1.480476
# ..        ...       ...       ...       ...       ...       ...       ...
# 403  4.264589  2.509735  0.424732 -2.362466 -0.267979  0.740181  0.607153
# 404  3.532961  2.543756 -1.597902  1.216960  2.269680  3.005442  0.781169
# 405  4.503617  3.609594  0.873510 -0.622927  0.322380 -0.396016 -1.871963
# 406  3.974814  3.752904  1.201134 -2.444935 -0.326141  1.403284 -0.333149
# 407  4.944123  0.468457  0.736605 -2.427006 -0.589758  0.248583 -0.572550
#
#           PC8       PC9      PC10      PC11      PC12      PC13      PC14  \
# 0    1.139169  1.238982 -0.836321  1.162174 -0.401364 -0.187779 -0.422133
# 1   -1.915688 -0.151857  0.680963  0.133825 -0.037708  0.475446  0.176649
# 2   -0.944424  0.021618 -1.619105 -0.209672  0.902524 -0.222268 -2.716124
# 3    2.020254  0.955674 -0.772978  1.213669  1.175079 -2.165321 -0.617606
# 4   -1.462676 -0.961912  0.919464  2.529386  1.864371  0.423266  0.363107
# ..        ...       ...       ...       ...       ...       ...       ...
# 403 -1.067221  1.548211 -1.850709  0.384054 -0.387274  1.035365  1.854229
# 404  2.604466  0.016765 -0.442147  0.513594  0.125594  1.050503  1.954158
# 405 -2.103838 -1.546398  0.745173 -0.000052  0.528785 -2.419767  0.258200
# 406 -0.480823  1.324068 -1.980160 -0.263011  0.639933 -0.240870  1.572840
# 407 -0.367929  0.217001 -0.269300 -0.958018  2.624763  2.008787  2.344409
#
#          PC15      PC16      PC17      PC18      PC19
# 0    0.057189 -1.518510 -0.062652  1.163590 -1.156244
# 1   -1.556511  0.470715  1.615023 -0.275578 -1.031961
# 2    1.199006 -1.087473  0.092507  0.049903  0.833417
# 3   -1.239795  0.217446 -0.793116  1.163687 -0.775299
# 4   -1.198708 -0.200602 -0.463910 -1.166012 -1.045293
# ..        ...       ...       ...       ...       ...
# 403 -0.881400 -0.987535  0.179824  1.344071 -1.112531
# 404  0.475130 -1.187265 -0.244805  0.392383  0.607496
# 405  1.172513 -1.333015  0.509634 -1.073383 -0.617757
# 406 -1.137106  1.149121  0.793669  0.473643 -0.384410
# 407  0.245959  0.220712 -0.130630 -0.272442  0.984934
#
# [408 rows x 19 columns]

# %% [markdown]
# #Model

# %%
# Lets select the proper random state to build best model by using LogisticRegression

acc_score_test = 0
acc_score_train = 0
rand_state = 0
for i in range(1,200):

    x_train,x_test,y_train,y_test = train_test_split(pca_x,y,test_size=0.3,random_state= i )

    lr = LinearRegression()
    lr.fit(x_train,y_train)

    y_pred=lr.predict(x_train) # prediction on train data
    r1 =r2_score(y_train,y_pred) # accuracy check on train data

    pred = lr.predict(x_test)   #prediction on test data
    r2 =r2_score(y_test,pred) #accuracy check on test data

    if r2 > acc_score_test and r1 > acc_score_train: # selecting max score accuracy
        acc_score_test = r2
        acc_score_train = r1
        rand_state = i
    print(f"at random sate {i}, the training accuracy is:- {acc_score_train}")
    print(f"at random sate {i}, the testing accuracy is:- {acc_score_test}")
    print("\n")
print('Best Training accuracy_score is {} on random state {}'.format(acc_score_train,rand_state))
print('Best Testing accuracy_score is {} on random state {}'.format(acc_score_test,rand_state))
# Out:
# at random sate 1, the training accuracy is:- 0.8415580290725088
# at random sate 1, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 2, the training accuracy is:- 0.8415580290725088
# at random sate 2, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 3, the training accuracy is:- 0.8415580290725088
# at random sate 3, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 4, the training accuracy is:- 0.8415580290725088
# at random sate 4, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 5, the training accuracy is:- 0.8415580290725088
# at random sate 5, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 6, the training accuracy is:- 0.8415580290725088
# at random sate 6, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 7, the training accuracy is:- 0.8415580290725088
# at random sate 7, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 8, the training accuracy is:- 0.8415580290725088
# at random sate 8, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 9, the training accuracy is:- 0.8415580290725088
# at random sate 9, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 10, the training accuracy is:- 0.8415580290725088
# at random sate 10, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 11, the training accuracy is:- 0.8415580290725088
# at random sate 11, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 12, the training accuracy is:- 0.8415580290725088
# at random sate 12, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 13, the training accuracy is:- 0.8415580290725088
# at random sate 13, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 14, the training accuracy is:- 0.8415580290725088
# at random sate 14, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 15, the training accuracy is:- 0.8415580290725088
# at random sate 15, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 16, the training accuracy is:- 0.8415580290725088
# at random sate 16, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 17, the training accuracy is:- 0.8415580290725088
# at random sate 17, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 18, the training accuracy is:- 0.8415580290725088
# at random sate 18, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 19, the training accuracy is:- 0.8415580290725088
# at random sate 19, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 20, the training accuracy is:- 0.8415580290725088
# at random sate 20, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 21, the training accuracy is:- 0.8415580290725088
# at random sate 21, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 22, the training accuracy is:- 0.8415580290725088
# at random sate 22, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 23, the training accuracy is:- 0.8415580290725088
# at random sate 23, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 24, the training accuracy is:- 0.8415580290725088
# at random sate 24, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 25, the training accuracy is:- 0.8415580290725088
# at random sate 25, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 26, the training accuracy is:- 0.8415580290725088
# at random sate 26, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 27, the training accuracy is:- 0.8415580290725088
# at random sate 27, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 28, the training accuracy is:- 0.8415580290725088
# at random sate 28, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 29, the training accuracy is:- 0.8415580290725088
# at random sate 29, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 30, the training accuracy is:- 0.8415580290725088
# at random sate 30, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 31, the training accuracy is:- 0.8415580290725088
# at random sate 31, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 32, the training accuracy is:- 0.8415580290725088
# at random sate 32, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 33, the training accuracy is:- 0.8415580290725088
# at random sate 33, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 34, the training accuracy is:- 0.8415580290725088
# at random sate 34, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 35, the training accuracy is:- 0.8415580290725088
# at random sate 35, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 36, the training accuracy is:- 0.8415580290725088
# at random sate 36, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 37, the training accuracy is:- 0.8415580290725088
# at random sate 37, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 38, the training accuracy is:- 0.8415580290725088
# at random sate 38, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 39, the training accuracy is:- 0.8415580290725088
# at random sate 39, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 40, the training accuracy is:- 0.8415580290725088
# at random sate 40, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 41, the training accuracy is:- 0.8415580290725088
# at random sate 41, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 42, the training accuracy is:- 0.8415580290725088
# at random sate 42, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 43, the training accuracy is:- 0.8415580290725088
# at random sate 43, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 44, the training accuracy is:- 0.8415580290725088
# at random sate 44, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 45, the training accuracy is:- 0.8415580290725088
# at random sate 45, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 46, the training accuracy is:- 0.8415580290725088
# at random sate 46, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 47, the training accuracy is:- 0.8415580290725088
# at random sate 47, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 48, the training accuracy is:- 0.8415580290725088
# at random sate 48, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 49, the training accuracy is:- 0.8415580290725088
# at random sate 49, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 50, the training accuracy is:- 0.8415580290725088
# at random sate 50, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 51, the training accuracy is:- 0.8415580290725088
# at random sate 51, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 52, the training accuracy is:- 0.8415580290725088
# at random sate 52, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 53, the training accuracy is:- 0.8415580290725088
# at random sate 53, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 54, the training accuracy is:- 0.8415580290725088
# at random sate 54, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 55, the training accuracy is:- 0.8415580290725088
# at random sate 55, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 56, the training accuracy is:- 0.8415580290725088
# at random sate 56, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 57, the training accuracy is:- 0.8415580290725088
# at random sate 57, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 58, the training accuracy is:- 0.8415580290725088
# at random sate 58, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 59, the training accuracy is:- 0.8415580290725088
# at random sate 59, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 60, the training accuracy is:- 0.8415580290725088
# at random sate 60, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 61, the training accuracy is:- 0.8415580290725088
# at random sate 61, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 62, the training accuracy is:- 0.8415580290725088
# at random sate 62, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 63, the training accuracy is:- 0.8415580290725088
# at random sate 63, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 64, the training accuracy is:- 0.8415580290725088
# at random sate 64, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 65, the training accuracy is:- 0.8415580290725088
# at random sate 65, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 66, the training accuracy is:- 0.8415580290725088
# at random sate 66, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 67, the training accuracy is:- 0.8415580290725088
# at random sate 67, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 68, the training accuracy is:- 0.8415580290725088
# at random sate 68, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 69, the training accuracy is:- 0.8415580290725088
# at random sate 69, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 70, the training accuracy is:- 0.8415580290725088
# at random sate 70, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 71, the training accuracy is:- 0.8415580290725088
# at random sate 71, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 72, the training accuracy is:- 0.8415580290725088
# at random sate 72, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 73, the training accuracy is:- 0.8415580290725088
# at random sate 73, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 74, the training accuracy is:- 0.8415580290725088
# at random sate 74, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 75, the training accuracy is:- 0.8415580290725088
# at random sate 75, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 76, the training accuracy is:- 0.8415580290725088
# at random sate 76, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 77, the training accuracy is:- 0.8415580290725088
# at random sate 77, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 78, the training accuracy is:- 0.8415580290725088
# at random sate 78, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 79, the training accuracy is:- 0.8415580290725088
# at random sate 79, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 80, the training accuracy is:- 0.8415580290725088
# at random sate 80, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 81, the training accuracy is:- 0.8415580290725088
# at random sate 81, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 82, the training accuracy is:- 0.8415580290725088
# at random sate 82, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 83, the training accuracy is:- 0.8415580290725088
# at random sate 83, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 84, the training accuracy is:- 0.8415580290725088
# at random sate 84, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 85, the training accuracy is:- 0.8415580290725088
# at random sate 85, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 86, the training accuracy is:- 0.8415580290725088
# at random sate 86, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 87, the training accuracy is:- 0.8415580290725088
# at random sate 87, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 88, the training accuracy is:- 0.8415580290725088
# at random sate 88, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 89, the training accuracy is:- 0.8415580290725088
# at random sate 89, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 90, the training accuracy is:- 0.8415580290725088
# at random sate 90, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 91, the training accuracy is:- 0.8415580290725088
# at random sate 91, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 92, the training accuracy is:- 0.8415580290725088
# at random sate 92, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 93, the training accuracy is:- 0.8415580290725088
# at random sate 93, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 94, the training accuracy is:- 0.8415580290725088
# at random sate 94, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 95, the training accuracy is:- 0.8415580290725088
# at random sate 95, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 96, the training accuracy is:- 0.8415580290725088
# at random sate 96, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 97, the training accuracy is:- 0.8415580290725088
# at random sate 97, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 98, the training accuracy is:- 0.8415580290725088
# at random sate 98, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 99, the training accuracy is:- 0.8415580290725088
# at random sate 99, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 100, the training accuracy is:- 0.8415580290725088
# at random sate 100, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 101, the training accuracy is:- 0.8415580290725088
# at random sate 101, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 102, the training accuracy is:- 0.8415580290725088
# at random sate 102, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 103, the training accuracy is:- 0.8415580290725088
# at random sate 103, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 104, the training accuracy is:- 0.8415580290725088
# at random sate 104, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 105, the training accuracy is:- 0.8415580290725088
# at random sate 105, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 106, the training accuracy is:- 0.8415580290725088
# at random sate 106, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 107, the training accuracy is:- 0.8415580290725088
# at random sate 107, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 108, the training accuracy is:- 0.8415580290725088
# at random sate 108, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 109, the training accuracy is:- 0.8415580290725088
# at random sate 109, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 110, the training accuracy is:- 0.8415580290725088
# at random sate 110, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 111, the training accuracy is:- 0.8415580290725088
# at random sate 111, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 112, the training accuracy is:- 0.8415580290725088
# at random sate 112, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 113, the training accuracy is:- 0.8415580290725088
# at random sate 113, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 114, the training accuracy is:- 0.8415580290725088
# at random sate 114, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 115, the training accuracy is:- 0.8415580290725088
# at random sate 115, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 116, the training accuracy is:- 0.8415580290725088
# at random sate 116, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 117, the training accuracy is:- 0.8415580290725088
# at random sate 117, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 118, the training accuracy is:- 0.8415580290725088
# at random sate 118, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 119, the training accuracy is:- 0.8415580290725088
# at random sate 119, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 120, the training accuracy is:- 0.8415580290725088
# at random sate 120, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 121, the training accuracy is:- 0.8415580290725088
# at random sate 121, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 122, the training accuracy is:- 0.8415580290725088
# at random sate 122, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 123, the training accuracy is:- 0.8415580290725088
# at random sate 123, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 124, the training accuracy is:- 0.8415580290725088
# at random sate 124, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 125, the training accuracy is:- 0.8415580290725088
# at random sate 125, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 126, the training accuracy is:- 0.8415580290725088
# at random sate 126, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 127, the training accuracy is:- 0.8415580290725088
# at random sate 127, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 128, the training accuracy is:- 0.8415580290725088
# at random sate 128, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 129, the training accuracy is:- 0.8415580290725088
# at random sate 129, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 130, the training accuracy is:- 0.8415580290725088
# at random sate 130, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 131, the training accuracy is:- 0.8415580290725088
# at random sate 131, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 132, the training accuracy is:- 0.8415580290725088
# at random sate 132, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 133, the training accuracy is:- 0.8415580290725088
# at random sate 133, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 134, the training accuracy is:- 0.8415580290725088
# at random sate 134, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 135, the training accuracy is:- 0.8415580290725088
# at random sate 135, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 136, the training accuracy is:- 0.8415580290725088
# at random sate 136, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 137, the training accuracy is:- 0.8415580290725088
# at random sate 137, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 138, the training accuracy is:- 0.8415580290725088
# at random sate 138, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 139, the training accuracy is:- 0.8415580290725088
# at random sate 139, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 140, the training accuracy is:- 0.8415580290725088
# at random sate 140, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 141, the training accuracy is:- 0.8415580290725088
# at random sate 141, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 142, the training accuracy is:- 0.8415580290725088
# at random sate 142, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 143, the training accuracy is:- 0.8415580290725088
# at random sate 143, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 144, the training accuracy is:- 0.8415580290725088
# at random sate 144, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 145, the training accuracy is:- 0.8415580290725088
# at random sate 145, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 146, the training accuracy is:- 0.8415580290725088
# at random sate 146, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 147, the training accuracy is:- 0.8415580290725088
# at random sate 147, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 148, the training accuracy is:- 0.8415580290725088
# at random sate 148, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 149, the training accuracy is:- 0.8415580290725088
# at random sate 149, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 150, the training accuracy is:- 0.8415580290725088
# at random sate 150, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 151, the training accuracy is:- 0.8415580290725088
# at random sate 151, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 152, the training accuracy is:- 0.8415580290725088
# at random sate 152, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 153, the training accuracy is:- 0.8415580290725088
# at random sate 153, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 154, the training accuracy is:- 0.8415580290725088
# at random sate 154, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 155, the training accuracy is:- 0.8415580290725088
# at random sate 155, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 156, the training accuracy is:- 0.8415580290725088
# at random sate 156, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 157, the training accuracy is:- 0.8415580290725088
# at random sate 157, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 158, the training accuracy is:- 0.8415580290725088
# at random sate 158, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 159, the training accuracy is:- 0.8415580290725088
# at random sate 159, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 160, the training accuracy is:- 0.8415580290725088
# at random sate 160, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 161, the training accuracy is:- 0.8415580290725088
# at random sate 161, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 162, the training accuracy is:- 0.8415580290725088
# at random sate 162, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 163, the training accuracy is:- 0.8415580290725088
# at random sate 163, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 164, the training accuracy is:- 0.8415580290725088
# at random sate 164, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 165, the training accuracy is:- 0.8415580290725088
# at random sate 165, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 166, the training accuracy is:- 0.8415580290725088
# at random sate 166, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 167, the training accuracy is:- 0.8415580290725088
# at random sate 167, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 168, the training accuracy is:- 0.8415580290725088
# at random sate 168, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 169, the training accuracy is:- 0.8415580290725088
# at random sate 169, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 170, the training accuracy is:- 0.8415580290725088
# at random sate 170, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 171, the training accuracy is:- 0.8415580290725088
# at random sate 171, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 172, the training accuracy is:- 0.8415580290725088
# at random sate 172, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 173, the training accuracy is:- 0.8415580290725088
# at random sate 173, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 174, the training accuracy is:- 0.8415580290725088
# at random sate 174, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 175, the training accuracy is:- 0.8415580290725088
# at random sate 175, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 176, the training accuracy is:- 0.8415580290725088
# at random sate 176, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 177, the training accuracy is:- 0.8415580290725088
# at random sate 177, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 178, the training accuracy is:- 0.8415580290725088
# at random sate 178, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 179, the training accuracy is:- 0.8415580290725088
# at random sate 179, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 180, the training accuracy is:- 0.8415580290725088
# at random sate 180, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 181, the training accuracy is:- 0.8415580290725088
# at random sate 181, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 182, the training accuracy is:- 0.8415580290725088
# at random sate 182, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 183, the training accuracy is:- 0.8415580290725088
# at random sate 183, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 184, the training accuracy is:- 0.8415580290725088
# at random sate 184, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 185, the training accuracy is:- 0.8415580290725088
# at random sate 185, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 186, the training accuracy is:- 0.8415580290725088
# at random sate 186, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 187, the training accuracy is:- 0.8415580290725088
# at random sate 187, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 188, the training accuracy is:- 0.8415580290725088
# at random sate 188, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 189, the training accuracy is:- 0.8415580290725088
# at random sate 189, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 190, the training accuracy is:- 0.8415580290725088
# at random sate 190, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 191, the training accuracy is:- 0.8415580290725088
# at random sate 191, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 192, the training accuracy is:- 0.8415580290725088
# at random sate 192, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 193, the training accuracy is:- 0.8415580290725088
# at random sate 193, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 194, the training accuracy is:- 0.8415580290725088
# at random sate 194, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 195, the training accuracy is:- 0.8415580290725088
# at random sate 195, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 196, the training accuracy is:- 0.8415580290725088
# at random sate 196, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 197, the training accuracy is:- 0.8415580290725088
# at random sate 197, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 198, the training accuracy is:- 0.8415580290725088
# at random sate 198, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 199, the training accuracy is:- 0.8415580290725088
# at random sate 199, the testing accuracy is:- 0.8120376086455556
#
#
# Best Training accuracy_score is 0.8415580290725088 on random state 1
# Best Testing accuracy_score is 0.8120376086455556 on random state 1

# %%
rand_state
# Out:
# 1

# %%
#Lets split for train and test data
x_train,x_test,y_train,y_test = train_test_split(pca_x,y,test_size=0.3,random_state= rand_state )

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (285, 19)
# (123, 19)
# (285,)
# (123,)

# %%
LR= LinearRegression()

dt=DecisionTreeRegressor()

ada=AdaBoostRegressor()
gb=GradientBoostingRegressor()

rfc= RandomForestRegressor()


xgb=xgb.XGBRegressor()

knn=KNeighborsRegressor()



models=[]
models.append(('LinearRegression', LR))
models.append(('DecisionTreeRegressor', dt))
models.append(('AdaBoostRegressor', ada))
models.append(('GradientBoostingRegressor', gb))
models.append(('RandomForestRegressor', rfc))
models.append(('XGBRegressor', xgb))
models.append(('KNeighborsRegressor', knn))

# %%
m=[]
score=[]
score2=[]
cv_score=[]
MAE_score=[]
MSE_score=[]
for name, model in models:
    print('***********************',name,'***********************')
    m.append(name)
    model.fit(x_train, y_train)
    print(model)
    y_pred=model.predict(x_train)
    AS=r2_score(y_train,y_pred)
    print("Train Report:",AS)
    score.append(AS*100)

    pred=model.predict(x_test)
    AS2=r2_score(y_test,pred)
    print("Test Report:",AS2)
    score2.append(AS2*100)
    MAE=mae(y_test,pred)
    print("Mean Squered Error:",MAE)
    MAE_score.append(MAE*100)
    MSE=mse(y_test,pred)
    print("Mean Absolute Error:", MSE)
    MSE_score.append(MSE*100)

    accuracies= cross_val_score(model,x,y, cv=2)
    print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
    cv_score.append(accuracies.mean()*100)
    print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
    print('\n')
# Out:
# *********************** LinearRegression ***********************
# LinearRegression()
# Train Report: 0.8415580290725088
# Test Report: 0.8120376086455556
# Mean Squered Error: 0.03956577865423232
# Mean Absolute Error: 0.002852207558491348
# Accuracy: 88.98 %
# Standard Deviation: 0.56 %
#
#
# *********************** DecisionTreeRegressor ***********************
# DecisionTreeRegressor()
# Train Report: 1.0
# Test Report: 0.1618495730229388
# Mean Squered Error: 0.08350878773574169
# Mean Absolute Error: 0.012718389916995487
# Accuracy: 78.71 %
# Standard Deviation: 3.18 %
#
#
# *********************** AdaBoostRegressor ***********************
# AdaBoostRegressor()
# Train Report: 0.8106520776413368
# Test Report: 0.5707025281055063
# Mean Squered Error: 0.06672664225138462
# Mean Absolute Error: 0.006514311109554577
# Accuracy: 86.33 %
# Standard Deviation: 0.90 %
#
#
# *********************** GradientBoostingRegressor ***********************
# GradientBoostingRegressor()
# Train Report: 0.9868898636376777
# Test Report: 0.6826744374096505
# Mean Squered Error: 0.05352605711936085
# Mean Absolute Error: 0.004815209902368129
# Accuracy: 93.83 %
# Standard Deviation: 2.84 %
#
#
# *********************** RandomForestRegressor ***********************
# RandomForestRegressor()
# Train Report: 0.9555954453376491
# Test Report: 0.6375749623620692
# Mean Squered Error: 0.05836405390928665
# Mean Absolute Error: 0.005499565228387244
# Accuracy: 91.19 %
# Standard Deviation: 2.70 %
#
#
# *********************** XGBRegressor ***********************
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# Train Report: 0.9999643327441963
# Test Report: 0.7028608635280236
# Mean Squered Error: 0.050365350032374544
# Mean Absolute Error: 0.004508893959381542
# Accuracy: 90.71 %
# Standard Deviation: 4.55 %
#
#
# *********************** KNeighborsRegressor ***********************
# KNeighborsRegressor()
# Train Report: 0.7237043543414674
# Test Report: 0.5182154766281781
# Mean Squered Error: 0.06624413170122229
# Mean Absolute Error: 0.007310768123469983
# Accuracy: -37.30 %
# Standard Deviation: 8.33 %

# %%
print(len(m),len(score),len(score2),len(cv_score),len(MAE_score),len(MSE_score))
# Out:
# 7 7 7 7 7 7

# %%
result = pd.DataFrame({'Model': m, 'Accuracy_train_score': score,'Accuracy_test_score': score2 ,'Cross_val_score':cv_score, 'MAE_score':MAE_score,'MSE_score':MSE_score })
result
# Out:
#                        Model  Accuracy_train_score  Accuracy_test_score  \
# 0           LinearRegression             84.155803            81.203761
# 1      DecisionTreeRegressor            100.000000            16.184957
# 2          AdaBoostRegressor             81.065208            57.070253
# 3  GradientBoostingRegressor             98.688986            68.267444
# 4      RandomForestRegressor             95.559545            63.757496
# 5               XGBRegressor             99.996433            70.286086
# 6        KNeighborsRegressor             72.370435            51.821548
#
#    Cross_val_score  MAE_score  MSE_score
# 0        88.982171   3.956578   0.285221
# 1        78.709124   8.350879   1.271839
# 2        86.329088   6.672664   0.651431
# 3        93.829457   5.352606   0.481521
# 4        91.194040   5.836405   0.549957
# 5        90.708009   5.036535   0.450889
# 6       -37.299920   6.624413   0.731077

# %%
result['lest_diff']=(result['Accuracy_test_score']-result['Cross_val_score'])
result
# Out:
#                        Model  Accuracy_train_score  Accuracy_test_score  \
# 0           LinearRegression             84.155803            81.203761
# 1      DecisionTreeRegressor            100.000000            16.184957
# 2          AdaBoostRegressor             81.065208            57.070253
# 3  GradientBoostingRegressor             98.688986            68.267444
# 4      RandomForestRegressor             95.559545            63.757496
# 5               XGBRegressor             99.996433            70.286086
# 6        KNeighborsRegressor             72.370435            51.821548
#
#    Cross_val_score  MAE_score  MSE_score  lest_diff
# 0        88.982171   3.956578   0.285221  -7.778410
# 1        78.709124   8.350879   1.271839 -62.524167
# 2        86.329088   6.672664   0.651431 -29.258835
# 3        93.829457   5.352606   0.481521 -25.562013
# 4        91.194040   5.836405   0.549957 -27.436544
# 5        90.708009   5.036535   0.450889 -20.421922
# 6       -37.299920   6.624413   0.731077  89.121467

# %%
# Hyper tuning by using RandomizedSearchCV With RandomForestClassifier

para={'n_jobs':range(1,55)}
rand=RandomizedSearchCV(estimator=LR, cv=5,param_distributions=para)
rand.fit(x_train,y_train)

rand.best_params_
# Out:
# {'n_jobs': 52}

# %%
LR= LinearRegression(n_jobs= 17)

LR.fit(x_train,y_train)
y_pred=ada.predict(x_train)
AS=r2_score(y_train,y_pred)
print("Train Report:",AS*100)
pred=LR.predict(x_test)
AS2=r2_score(y_test,pred)
print("Test Report:",AS2*100)
MAE=mae(y_test,pred)
print("Mean Squered Error:",MAE)
MSE=mse(y_test,pred)
print("Mean Absolute Error:", MSE)

accuracies= cross_val_score(LR,x_scaled, y, cv=5)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
cv_score.append(accuracies.mean()*100)
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Train Report: 81.06520776413369
# Test Report: 81.20376086455556
# Mean Squered Error: 0.03956577865423232
# Mean Absolute Error: 0.002852207558491348
# Accuracy: 92.06 %
# Standard Deviation: 0.97 %
